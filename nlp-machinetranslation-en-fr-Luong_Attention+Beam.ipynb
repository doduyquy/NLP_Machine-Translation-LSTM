# %% [markdown]
# <a href="https://colab.research.google.com/github/doduyquy/NLP_Machine-Translation-LSTM/blob/main/nlp-machinetranslation-en-fr-Luong_Attention%2BBeam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 2.1.0+cu121
# True
# NVIDIA GeForce RTX 3050 Laptop GPU

# %%
# !pip install spacy nltk --user
# !python -m spacy download en_core_web_sm
# !python -m spacy download fr_core_news_sm
# Out:
# Requirement already satisfied: spacy in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (3.8.11)
# Requirement already satisfied: nltk in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (3.9.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from spacy) (8.3.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\dang khoa\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: jinja2 in c:\users\dang khoa\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from spacy) (25.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from spacy) (0.20.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\dang khoa\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: setuptools in c:\users\dang khoa\appdata\local\programs\python\python310\lib\site-packages (from spacy) (65.5.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from spacy) (0.4.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: joblib in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: click in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\dang khoa\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dang khoa\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dang khoa\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dang khoa\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.11.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dang khoa\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: colorama in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dang khoa\appdata\local\programs\python\python310\lib\site-packages (from jinja2->spacy) (3.0.3)
# Requirement already satisfied: wrapt in c:\users\dang khoa\appdata\roaming\python\python310\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (2.0.1)
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 660.6 kB/s eta 0:00:20
#      --------------------------------------- 0.0/12.8 MB 495.5 kB/s eta 0:00:26
#      --------------------------------------- 0.1/12.8 MB 656.4 kB/s eta 0:00:20
#      --------------------------------------- 0.1/12.8 MB 656.4 kB/s eta 0:00:20
#       -------------------------------------- 0.2/12.8 MB 958.4 kB/s eta 0:00:14
#       -------------------------------------- 0.3/12.8 MB 983.0 kB/s eta 0:00:13
#       --------------------------------------- 0.3/12.8 MB 1.1 MB/s eta 0:00:12
#      - -------------------------------------- 0.4/12.8 MB 1.0 MB/s eta 0:00:13
#      - -------------------------------------- 0.4/12.8 MB 1.1 MB/s eta 0:00:12
#      - -------------------------------------- 0.6/12.8 MB 1.3 MB/s eta 0:00:10
#      -- ------------------------------------- 0.7/12.8 MB 1.4 MB/s eta 0:00:09
#      -- ------------------------------------- 0.8/12.8 MB 1.4 MB/s eta 0:00:09
#      -- ------------------------------------- 0.9/12.8 MB 1.5 MB/s eta 0:00:08
#      -- ------------------------------------- 0.9/12.8 MB 1.5 MB/s eta 0:00:09
#      --- ------------------------------------ 1.0/12.8 MB 1.5 MB/s eta 0:00:09
#      --- ------------------------------------ 1.0/12.8 MB 1.4 MB/s eta 0:00:09
#      --- ------------------------------------ 1.1/12.8 MB 1.4 MB/s eta 0:00:09
#      --- ------------------------------------ 1.1/12.8 MB 1.4 MB/s eta 0:00:09
#      --- ------------------------------------ 1.2/12.8 MB 1.4 MB/s eta 0:00:09
#      ---- ----------------------------------- 1.3/12.8 MB 1.5 MB/s eta 0:00:08
#      ---- ----------------------------------- 1.4/12.8 MB 1.5 MB/s eta 0:00:08
#      ---- ----------------------------------- 1.4/12.8 MB 1.4 MB/s eta 0:00:08
#      ---- ----------------------------------- 1.5/12.8 MB 1.5 MB/s eta 0:00:08
#      ----- ---------------------------------- 1.7/12.8 MB 1.5 MB/s eta 0:00:08
#      ----- ---------------------------------- 1.8/12.8 MB 1.6 MB/s eta 0:00:08
#      ------ --------------------------------- 1.9/12.8 MB 1.6 MB/s eta 0:00:07
#      ------ --------------------------------- 2.1/12.8 MB 1.7 MB/s eta 0:00:07
#      ------ --------------------------------- 2.2/12.8 MB 1.7 MB/s eta 0:00:07
#      ------- -------------------------------- 2.3/12.8 MB 1.7 MB/s eta 0:00:07
#      ------- -------------------------------- 2.4/12.8 MB 1.8 MB/s eta 0:00:06
#      ------- -------------------------------- 2.5/12.8 MB 1.8 MB/s eta 0:00:06
#      -------- ------------------------------- 2.6/12.8 MB 1.8 MB/s eta 0:00:06
#      -------- ------------------------------- 2.8/12.8 MB 1.8 MB/s eta 0:00:06
#      -------- ------------------------------- 2.8/12.8 MB 1.8 MB/s eta 0:00:06
#      -------- ------------------------------- 2.8/12.8 MB 1.8 MB/s eta 0:00:06
#      -------- ------------------------------- 2.8/12.8 MB 1.8 MB/s eta 0:00:06
#      -------- ------------------------------- 2.8/12.8 MB 1.8 MB/s eta 0:00:06
#      -------- ------------------------------- 2.8/12.8 MB 1.6 MB/s eta 0:00:07
#      --------- ------------------------------ 2.9/12.8 MB 1.6 MB/s eta 0:00:07
#      --------- ------------------------------ 2.9/12.8 MB 1.6 MB/s eta 0:00:07
#      --------- ------------------------------ 3.0/12.8 MB 1.6 MB/s eta 0:00:07
#      --------- ------------------------------ 3.0/12.8 MB 1.6 MB/s eta 0:00:07
#      --------- ------------------------------ 3.0/12.8 MB 1.6 MB/s eta 0:00:07
#      --------- ------------------------------ 3.0/12.8 MB 1.6 MB/s eta 0:00:07
#      --------- ------------------------------ 3.0/12.8 MB 1.6 MB/s eta 0:00:07
#      --------- ------------------------------ 3.1/12.8 MB 1.5 MB/s eta 0:00:07
#      --------- ------------------------------ 3.2/12.8 MB 1.5 MB/s eta 0:00:07
#      ---------- ----------------------------- 3.2/12.8 MB 1.5 MB/s eta 0:00:07
#      ---------- ----------------------------- 3.2/12.8 MB 1.5 MB/s eta 0:00:07
#      ---------- ----------------------------- 3.2/12.8 MB 1.5 MB/s eta 0:00:07
#      ---------- ----------------------------- 3.2/12.8 MB 1.5 MB/s eta 0:00:07
#      ---------- ----------------------------- 3.2/12.8 MB 1.4 MB/s eta 0:00:08
#      ---------- ----------------------------- 3.3/12.8 MB 1.3 MB/s eta 0:00:08
#      ---------- ----------------------------- 3.3/12.8 MB 1.3 MB/s eta 0:00:08
#      ---------- ----------------------------- 3.4/12.8 MB 1.4 MB/s eta 0:00:07
#      ---------- ----------------------------- 3.4/12.8 MB 1.3 MB/s eta 0:00:08
#      ---------- ----------------------------- 3.5/12.8 MB 1.3 MB/s eta 0:00:08
#      ---------- ----------------------------- 3.5/12.8 MB 1.3 MB/s eta 0:00:08
#      ---------- ----------------------------- 3.5/12.8 MB 1.3 MB/s eta 0:00:08
#      ----------- ---------------------------- 3.5/12.8 MB 1.3 MB/s eta 0:00:08
#      ----------- ---------------------------- 3.6/12.8 MB 1.3 MB/s eta 0:00:08
#      ----------- ---------------------------- 3.6/12.8 MB 1.3 MB/s eta 0:00:08
#      ----------- ---------------------------- 3.6/12.8 MB 1.3 MB/s eta 0:00:08
#      ----------- ---------------------------- 3.6/12.8 MB 1.3 MB/s eta 0:00:08
#      ----------- ---------------------------- 3.7/12.8 MB 1.2 MB/s eta 0:00:08
#      ----------- ---------------------------- 3.7/12.8 MB 1.2 MB/s eta 0:00:08
#      ----------- ---------------------------- 3.7/12.8 MB 1.2 MB/s eta 0:00:08
#      ----------- ---------------------------- 3.7/12.8 MB 1.2 MB/s eta 0:00:08
#      ----------- ---------------------------- 3.7/12.8 MB 1.2 MB/s eta 0:00:08
#      ----------- ---------------------------- 3.8/12.8 MB 1.2 MB/s eta 0:00:08
#      ----------- ---------------------------- 3.8/12.8 MB 1.2 MB/s eta 0:00:08
#      ------------ --------------------------- 3.9/12.8 MB 1.2 MB/s eta 0:00:08
#      ------------ --------------------------- 3.9/12.8 MB 1.2 MB/s eta 0:00:08
#      ------------ --------------------------- 3.9/12.8 MB 1.2 MB/s eta 0:00:08
#      ------------ --------------------------- 3.9/12.8 MB 1.2 MB/s eta 0:00:08
#      ------------ --------------------------- 3.9/12.8 MB 1.1 MB/s eta 0:00:08
#      ------------ --------------------------- 4.0/12.8 MB 1.1 MB/s eta 0:00:08
#      ------------ --------------------------- 4.0/12.8 MB 1.1 MB/s eta 0:00:08
#      ------------ --------------------------- 4.0/12.8 MB 1.1 MB/s eta 0:00:08
#      ------------ --------------------------- 4.0/12.8 MB 1.1 MB/s eta 0:00:08
#      ------------ --------------------------- 4.0/12.8 MB 1.1 MB/s eta 0:00:08
#      ------------ --------------------------- 4.0/12.8 MB 1.1 MB/s eta 0:00:08
#      ------------ --------------------------- 4.0/12.8 MB 1.1 MB/s eta 0:00:09
#      ------------ --------------------------- 4.1/12.8 MB 1.0 MB/s eta 0:00:09
#      ------------ --------------------------- 4.1/12.8 MB 1.0 MB/s eta 0:00:09
#      ------------ --------------------------- 4.1/12.8 MB 1.0 MB/s eta 0:00:09
#      ------------ --------------------------- 4.1/12.8 MB 1.0 MB/s eta 0:00:09
#      ------------ --------------------------- 4.1/12.8 MB 1.0 MB/s eta 0:00:09
#      ------------ --------------------------- 4.2/12.8 MB 1.0 MB/s eta 0:00:09
#      ------------- -------------------------- 4.2/12.8 MB 1.0 MB/s eta 0:00:09
#      ------------- -------------------------- 4.2/12.8 MB 1.0 MB/s eta 0:00:09
#      ------------ -------------------------- 4.2/12.8 MB 998.9 kB/s eta 0:00:09
#      ------------ -------------------------- 4.2/12.8 MB 994.0 kB/s eta 0:00:09
#      ------------ -------------------------- 4.2/12.8 MB 984.2 kB/s eta 0:00:09
#      ------------ -------------------------- 4.2/12.8 MB 983.2 kB/s eta 0:00:09
#      ------------- ------------------------- 4.3/12.8 MB 975.0 kB/s eta 0:00:09
#      ------------- ------------------------- 4.3/12.8 MB 968.1 kB/s eta 0:00:09
/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # 1. IMPORT LIBS, DEPENDENCIES,... & SETUP ENVIRONMENT

# %% [markdown]
# ## 1.1 Import all necessary dependencies

# %%
# Tokenizer
import spacy

# Build vocabulary
from collections import Counter

# Build model
import torch
import torch.nn as nn
import torch.optim as optim

# Load dataset for model
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence

# BLEU score
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import corpus_bleu

# Another (utils)
import matplotlib.pyplot as plt
import time
import random
from tqdm import tqdm
import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"- Device for training: {device} - {torch.cuda.get_device_name(0)}")
# Out:
# - Device for training: cuda - NVIDIA GeForce RTX 3050 Laptop GPU

# %% [markdown]
# ## 1.2 Connect to GG Drive

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# # Show the result
# dataset_path = "/content/drive/My Drive/021.SGU/01.Subjects/NLP/Dataset/"
# !ls "$dataset_path"

# %% [markdown]
# ## 1.3 Set constant

# %%
# GGDRIVE_DATASET_DIR_PATH = "/content/drive/My Drive/021.SGU/01.Subjects/NLP/Dataset/"
# ----------------------------------------
""" [4] Build vocab
- <pad> - 0: padding, add to short sentences to have the same length with long sentences in Batch
- <unk> - 1: unknown, index for some unknown words (token)
- <sos> - 2: start of sentence
- <eos> - 3: end of sentence
"""
SPECIAL_TOKENS_CONST = ["<pad>", "<unk>", "<sos>", "<eos>"]
VOCAB_MAX_SIZE_CONST = 10000  # 10.000 most common words


#----- Change for optimize model -----#
#--- [DEFAULT] ~ [BASELINE]
# [5] Dataset & DataLoader
TRAIN_LOADER_BATCH_SIZE_DEFAULT     =   32
# [6] LSTM layers
LSTM_NUM_LAYERS_DEFAULT             =   2
LSTM_DROPOUT_DEFAULT                =   0.3
LSTM_TEACHER_FORCING_DEFAULT        =   0.5
LSTM_EMBED_DIM_DEFAULT              =   256
LSTM_HIDDEN_DIM_DEFAULT             =   512
# [7] TRAINING + VALIDATION + EARLY STOPPING
MODEL_LEARNING_RATE_DEFAULT         =   0.001
MODEL_EPOCHS_DEFAULT                =   20
MODEL_EARLY_STOP_PATIENCE_DEFAULT   =   3

#--- [V1: deeper LSTM layers]
# ...
# ...

#--- CURRENT ---#
TRAIN_LOADER_BATCH_SIZE_CURRENT = TRAIN_LOADER_BATCH_SIZE_DEFAULT
LSTM_NUM_LAYERS_CURRENT = LSTM_NUM_LAYERS_DEFAULT
LSTM_DROPOUT_CURRENT = LSTM_DROPOUT_DEFAULT
LSTM_TEACHER_FORCING_CURRENT = LSTM_TEACHER_FORCING_DEFAULT
LSTM_EMBED_DIM_CURRENT = LSTM_EMBED_DIM_DEFAULT
LSTM_HIDDEN_DIM_CURRENT = LSTM_HIDDEN_DIM_DEFAULT
MODEL_LEARNING_RATE_CURRENT = MODEL_LEARNING_RATE_DEFAULT
MODEL_EPOCHS_CURRENT = MODEL_EPOCHS_DEFAULT
MODEL_EARLY_STOP_PATIENCE_CURRENT = MODEL_EARLY_STOP_PATIENCE_DEFAULT
#-------------------------------------#

# %% [markdown]
# # 2. LOAD DATA

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# Show the result
# dataset_path = "/content/drive/My Drive/021.SGU/01.Subjects/NLP/Dataset/"
dataset_path = "./data"
# !ls "$dataset_path"

def load_file(path):
    with open(path, 'r', encoding='utf-8') as file:
        # Remove abundant space at head/tail
        return [line.strip() for line in file]

train_en = load_file(f"{dataset_path}/train.en")
train_fr = load_file(f"{dataset_path}/train.fr")

val_en = load_file(f"{dataset_path}/val.en")
val_fr = load_file(f"{dataset_path}/val.fr")

test_en = load_file(f"{dataset_path}/test.en")
test_fr = load_file(f"{dataset_path}/test.fr")


print(f"- train.en size:    {len(train_en)}")
print(f"- train.fr size:    {len(train_fr)}")

print(f"- val.en size:    {len(val_en)}")
print(f"- val.fr size:    {len(val_fr)}")

print(f"- test.en size:    {len(test_en)}")
print(f"- test.fr size:    {len(test_fr)}")

print("-"*69)
print(f"- train.en example: {train_en[0]}")
print(f"- train.fr example: {train_fr[0]}")
# Out:
# - train.en size:    29000
# - train.fr size:    29000
# - val.en size:    1014
# - val.fr size:    1014
# - test.en size:    1071
# - test.fr size:    1071
# ---------------------------------------------------------------------
# - train.en example: Two young, White males are outside near many bushes.
# - train.fr example: Deux jeunes hommes blancs sont dehors près de buissons.

# %% [markdown]
# # 3. TOKENIZATION

# %%
# Load spacy's pre-trained models
nlp_en = spacy.load("en_core_web_sm")   # small English core, train with data in the internet
nlp_fr = spacy.load("fr_core_news_sm")  # small French core, train with news in French language

def en_tokenizer(text):
    # return lower token
    return [tok.text.lower() for tok in nlp_en.tokenizer(text)]
def fr_tokenizer(text):
    return [tok.text.lower() for tok in nlp_fr.tokenizer(text)]

# %%
# Tokenize our dataset files: train_en, train_fr, val_en, val_fr, test_en, test_fr.

train_en_tok = [en_tokenizer(sentence) for sentence in train_en]
train_fr_tok = [fr_tokenizer(sentence) for sentence in train_fr]

val_en_tok = [en_tokenizer(sentence) for sentence in val_en]
val_fr_tok = [fr_tokenizer(sentence) for sentence in val_fr]

test_en_tok = [en_tokenizer(sentence) for sentence in test_en]
test_fr_tok = [fr_tokenizer(sentence) for sentence in test_fr]

# %%
print(f"- train_en_tok: {train_en_tok[0]}")
print(f"- train_fr_tok: {train_fr_tok[0]}")
print(f"- val_en_tok: {val_en_tok[0]}")
print(f"- val_fr_tok: {val_fr_tok[0]}")
print(f"- test_en_tok: {test_en_tok[0]}")
print(f"- test_fr_tok: {test_fr_tok[0]}")
# Out:
# - train_en_tok: ['two', 'young', ',', 'white', 'males', 'are', 'outside', 'near', 'many', 'bushes', '.']
# - train_fr_tok: ['deux', 'jeunes', 'hommes', 'blancs', 'sont', 'dehors', 'près', 'de', 'buissons', '.']
# - val_en_tok: ['a', 'group', 'of', 'men', 'are', 'loading', 'cotton', 'onto', 'a', 'truck']
# - val_fr_tok: ['un', 'groupe', "d'", 'hommes', 'chargent', 'du', 'coton', 'dans', 'un', 'camion']
# - test_en_tok: ['a', 'young', 'man', 'participates', 'in', 'a', 'career', 'while', 'the', 'subject', 'who', 'records', 'it', 'smiles', '.']
# - test_fr_tok: ['un', 'jeune', 'homme', 'participe', 'à', 'une', 'course', 'pendant', 'que', 'le', 'sujet', 'qui', 'le', 'filme', 'sourit', '.']

# %% [markdown]
# # 4. BUILD VOCABULARY

# %%
# Numericalization, word <--> index
class Vocab:
    def __init__(self, tokens, max_size=VOCAB_MAX_SIZE_CONST):
        # Get dictionary: {word, frequence}
        self.freq = Counter(tokens)
        # Get only VOCAB_MAX_SIZE words
        most_common = self.freq.most_common(max_size)

        # Set list words of SPECIAL_TOKENS and most_common words
        self.itos = SPECIAL_TOKENS_CONST + [word for word, _ in most_common]
        # Set dict for each items in the list above
        self.stoi = {word:idx for idx, word in enumerate(self.itos)}

    """ Numericalize:
        We only get VOCAB_MAX_SIZE = 10.000 (for special tokens and most common word),
        so some tokens in our dataset will not map this vocal (None for the result)
        Therefore, we have to map all token which is not existed in lists word(self.itos) be built above
        to <unk> - 1.

        return: numerical tokens
    """
    def numericalize(self, tokens):
        return [self.stoi.get(tok, self.stoi.get('<unk>')) for tok in tokens]

    def __len__(self):
        return len(self.itos)

vocab_en = Vocab(tok for sentence in train_en_tok for tok in sentence)
vocab_fr = Vocab(tok for sentence in train_fr_tok for tok in sentence)

# Get some special index
PAD_IDX = vocab_fr.stoi.get('<pad>')
SOS_IDX = vocab_fr.stoi.get('<sos>')
EOS_IDX = vocab_fr.stoi.get('<eos>')

# %%
print(vocab_en.itos[0:10])
print("- Index of 'man': ",vocab_en.stoi.get('not-in-vocab'))

print()
print(f"- <pad> index: {PAD_IDX}")
print(f"- <sos> index: {SOS_IDX}")
print(f"- <eos> index: {EOS_IDX}")
# Out:
# ['<pad>', '<unk>', '<sos>', '<eos>', 'a', '.', 'in', 'the', 'on', 'man']
# - Index of 'man':  None
#
# - <pad> index: 0
# - <sos> index: 2
# - <eos> index: 3

# %% [markdown]
# # 5. DATASET & DATALOADER

# %%
class TranslationDataset(Dataset):
    def __init__(self, train_en_tok, train_fr_tok, vocab_en, vocab_fr):
        self.en = train_en_tok
        self.fr = train_fr_tok
        self.vocab_en = vocab_en
        self.vocab_fr = vocab_fr

    def __len__(self):
        return len(self.en)

    def __getitem__(self, idx):
        # Insert padding: <sos> and <eos>
        en_tokens = ["<sos>"] + self.en[idx] + ["<eos>"]
        fr_tokens = ["<sos>"] + self.fr[idx] + ["<eos>"]

        en_idx_in_vocab_en = self.vocab_en.numericalize(en_tokens)
        fr_idx_in_vocab_fr = self.vocab_fr.numericalize(fr_tokens)

        # return a tuple tensor index
        return torch.tensor(en_idx_in_vocab_en), torch.tensor(fr_idx_in_vocab_fr)

# %%
# Padding for short sentences in each batch
def collate_fn_baseline(batch):
    # Split sequence to english sentence and french sentence
    en_batch, fr_batch = zip(*batch)

    """ Padding:
        1. Find the max length
        2. Insert <pad> - 0 to the tail of short sentences. e.g:
            First 1: [1, 10, 11, 12, 2] (keep, the longest sentence)
            Second 2: [1, 13, 2, **0**, **0**] (append two <pad>-0)
        3. Stacking (by columns: column - batch, row - timestep)
                    1   1
                    10  13
                    11  2
                    12  0
                    2   0
    """
    en_batch = pad_sequence(en_batch, padding_value=PAD_IDX)
    fr_batch = pad_sequence(fr_batch, padding_value=PAD_IDX)

    return en_batch, fr_batch

# Add pack_padded_sequence and sort batch desc by length
def collate_fn(batch):
    # Split sequence to english sentence and french sentence
    en_batch, fr_batch = zip(*batch)

    # 1. Get real length before padding
    en_lens = torch.tensor([len(x) for x in en_batch])
    fr_lens = torch.tensor([len(x) for x in fr_batch])

    # 2. Sort by english length (desc) - required for pack_padded_sequence
    en_lens, sort_idx = en_lens.sort(descending=True)
    en_batch = [en_batch[i] for i in sort_idx]
    fr_batch = [fr_batch[i] for i in sort_idx]
    fr_lens = fr_lens[sort_idx] # sort french math with english

    # 3. Padding
    en_pad = pad_sequence(en_batch, padding_value=PAD_IDX)
    fr_pad = pad_sequence(fr_batch, padding_value=PAD_IDX)

    # 4. Return padded sequence and real length
    return en_pad, fr_pad, en_lens, fr_lens

# %%
train_dataset = TranslationDataset(train_en_tok, train_fr_tok, vocab_en, vocab_fr)
val_dataset = TranslationDataset(val_en_tok, val_fr_tok, vocab_en, vocab_fr)
test_dataset = TranslationDataset(test_en_tok, test_fr_tok, vocab_en, vocab_fr)


# For train dataset, we should shuffle it to avoid overfitting.
train_loader = DataLoader(
    train_dataset,
    batch_size=TRAIN_LOADER_BATCH_SIZE_CURRENT,
    shuffle=True,
    collate_fn=collate_fn
)

val_loader = DataLoader(
    val_dataset,
    batch_size=TRAIN_LOADER_BATCH_SIZE_CURRENT,
    shuffle=False,
    collate_fn=collate_fn
)

test_loader = DataLoader(
    test_dataset,
    batch_size=1,
    shuffle=False,
    collate_fn=collate_fn
)

# %%
# shape: [Sequence_Length, Batch_Size], because LSTM/RNN in Pytorch handle data by timestep
batch_train_en, batch_train_fr, batch_train_en_lens, batch_train_fr_lens = next(iter(train_loader))
batch_val_en, batch_val_fr, batch_val_en_lens, batch_val_fr_lens = next(iter(val_loader))
batch_test_en, batch_test_fr, batch_test_en_lens, batch_test_fr_lens = next(iter(test_loader))

print(f"Train - EN: {batch_train_en.shape}, FR: {batch_train_fr.shape}")
print(f"Train - EN lens: {batch_train_en_lens}, FR lens: {batch_train_fr_lens}")
print()
print(f"Val - EN: {batch_val_en.shape}, FR: {batch_val_fr.shape}")
print(f"Val - EN lens: {batch_val_en_lens}, FR lens: {batch_val_fr_lens}")
print()
print(f"Test - EN: {batch_test_en.shape}, FR: {batch_test_fr.shape}")
print(f"Test - EN lens: {batch_test_en_lens}, FR lens: {batch_test_fr_lens}")
# Out:
# Train - EN: torch.Size([22, 32]), FR: torch.Size([25, 32])
# Train - EN lens: tensor([22, 22, 22, 22, 21, 20, 19, 19, 19, 18, 18, 17, 17, 17, 16, 16, 16, 15,
#         14, 14, 14, 14, 14, 13, 13, 12, 12, 12, 11, 10, 10,  7]), FR lens: tensor([24, 23, 24, 25, 19, 21, 25, 18, 22, 21, 19, 17, 19, 20, 16, 14, 16, 16,
#         14, 19, 16, 12, 15, 13, 14, 13, 14, 14, 11, 11, 13, 11])
#
# Val - EN: torch.Size([27, 32]), FR: torch.Size([27, 32])
# Val - EN lens: tensor([27, 20, 20, 19, 18, 18, 17, 17, 17, 16, 16, 15, 15, 14, 13, 13, 13, 13,
#         13, 13, 13, 13, 13, 13, 12, 12, 12, 12, 12, 11, 11, 11]), FR lens: tensor([27, 16, 22, 24, 25, 19, 19, 14, 22, 16, 20, 15, 17, 14, 13, 16, 13, 15,
#         13, 14, 11, 14, 11, 15, 12, 11, 11, 12, 11, 11, 11, 11])
#
# Test - EN: torch.Size([17, 1]), FR: torch.Size([18, 1])
# Test - EN lens: tensor([17]), FR lens: tensor([18])

# %% [markdown]
# # Attention

# %%
class LuongAttention(nn.Module):
    def __init__(self, hidden_dim):
        super().__init__()
        self.hidden_dim = hidden_dim

    def forward(self, decoder_hidden, encoder_outputs):
        """
        decoder_hidden: [num_layers, batch, hidden]
        encoder_outputs: [src_len, batch, hidden]
        """
        # lấy hidden của layer cuối: [batch, hidden]
        decoder_hidden = decoder_hidden[-1].unsqueeze(2)  # [batch, hidden, 1]

        # Score = encoder_output · decoder_hidden
        # encoder_outputs: [src_len, batch, hidden]
        # sau permute:    [batch, src_len, hidden]
        scores = torch.bmm(
            encoder_outputs.permute(1,0,2),
            decoder_hidden
        ).squeeze(2)  # [batch, src_len]

        attn_weights = torch.softmax(scores, dim=1)  # [batch, src_len]

        return attn_weights

# %% [markdown]
# # 6. ENCODER-DECODER, SEQ2SEQ MODEL

# %%
class Encoder(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_layers=LSTM_NUM_LAYERS_DEFAULT, dropout=LSTM_DROPOUT_DEFAULT):
        super().__init__()

        # src shape e.g: [10, 32] - [Sequence_length, Batch_size]
        """ embed_dim: vector size for each word
            - Create matrix (A) with shape: [vocab_size, embed_dim], each row represent for each word,
            e.g: src shape: [10, 32], elements are the index of words in vocab, so we get the row of that index in matrix (A)
            - Result: a matrix with shape [10, 32, 256]
        """
        self.embedding = nn.Embedding(vocab_size, embed_dim)

        """ hidden_dim: vector size for hidden state
            - Result: e.g [10, 32, 512]
        """
        self.lstm = nn.LSTM(embed_dim, hidden_dim,
                            num_layers=num_layers,  # use num_layers(2) layers LSTM
                            dropout=dropout)    # randomly turn off neuron to avoid overfitting

    def forward(self, src, src_lens):
        # src: [seq_len, batch_size]
        # src_len: [batch_size] - sorted (desc)

        embedded = self.embedding(src)

        # Pack padded sequence
        packed = nn.utils.rnn.pack_padded_sequence(
            embedded,
            src_lens.cpu(), # require length at CPU
            enforce_sorted=True
        )
        # LSTM forward
        packed_outputs, (hidden, cell) = self.lstm(packed)
        # Unpack
        outputs, _ = nn.utils.rnn.pad_packed_sequence(packed_outputs)

        return outputs, hidden, cell

class Decoder(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_layers=LSTM_NUM_LAYERS_DEFAULT, dropout=LSTM_DROPOUT_DEFAULT):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.lstm = nn.LSTM(embed_dim, hidden_dim,
                            num_layers=num_layers,
                            dropout=dropout)
        # Attention module
        self.attention = LuongAttention(hidden_dim)

        # Fully connected - input size is hidden_dim * 2 (context + decoder output)
        self.fc = nn.Linear(hidden_dim * 2, vocab_size)

    def forward(self, input, hidden, cell, encoder_outputs):
        # input: a word
        # encoder_outputs: [src_len, batch, hidden]
        input = input.unsqueeze(0)
        embedded = self.embedding(input)

        output, (hidden, cell) = self.lstm(embedded, (hidden, cell))

        # Apply attention: output shape [batch, hidden]
        attn_weights = self.attention(hidden, encoder_outputs)  # [batch, src_len]

        # Context vector: weighted sum of encoder outputs
        # attn_weights: [batch, src_len] -> [batch, 1, src_len]
        # encoder_outputs: [src_len, batch, hidden] -> [batch, src_len, hidden]
        context = torch.bmm(
            attn_weights.unsqueeze(1),  # [batch, 1, src_len]
            encoder_outputs.permute(1, 0, 2)  # [batch, src_len, hidden]
        ).squeeze(1)  # [batch, hidden]

        # Concatenate context and decoder output
        combined = torch.cat([output.squeeze(0), context], dim=1)  # [batch, hidden*2]

        # prediction shape: [batch, vocab_size]
        prediction = self.fc(combined)

        return prediction, hidden, cell, attn_weights


class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, src, trg, src_lens, teacher_forcing=LSTM_TEACHER_FORCING_DEFAULT):
        # src (en): [src_len, batch_size]
        # trg (fr): [trg_len, batch_size]
        # src_lens: [batch_size]

        batch_size = trg.size(1)
        max_len = trg.size(0)
        vocab_size = self.decoder.fc.out_features

        # a zero tensor (default) contain output
        outputs = torch.zeros(max_len, batch_size, vocab_size).to(src.device)

        #--- Get Context Vector from Encoder:
        encoder_outputs, hidden, cell = self.encoder(src, src_lens)

        # token <sos>
        input_token = trg[0, :]

        for timestep in range(1, max_len):
            output, hidden, cell, _ = self.decoder(input_token, hidden, cell, encoder_outputs)
            outputs[timestep] = output

            best_guess = output.argmax(1)

            # teacher_forcing:
            # random < teacher_forcing ratio: trg[timestep], the true target
            # random >= teacher_forcing ratio: the best_guess
            input_token = trg[timestep] if random.random() < teacher_forcing else best_guess

        return outputs

# %%
input_dim = len(vocab_en)
output_dim = len(vocab_fr)
# print(input_dim, output_dim)

encoder = Encoder(vocab_size=input_dim, embed_dim=LSTM_EMBED_DIM_CURRENT, hidden_dim=LSTM_HIDDEN_DIM_CURRENT, num_layers=LSTM_NUM_LAYERS_CURRENT).to(device)  # 256, 512
decoder = Decoder(vocab_size=output_dim, embed_dim=LSTM_EMBED_DIM_CURRENT, hidden_dim=LSTM_HIDDEN_DIM_CURRENT, num_layers=LSTM_NUM_LAYERS_CURRENT).to(device)  # 256, 512

model = Seq2Seq(encoder, decoder).to(device)

# Ignore computing loss for PAD_IDX
criterion = nn.CrossEntropyLoss(ignore_index=PAD_IDX)
optimizer = optim.Adam(params=model.parameters(), lr=MODEL_LEARNING_RATE_CURRENT)

# %% [markdown]
# # Inference Function

# %%
def translate(sentence):
    model.eval()

    # tokenize
    tokens = en_tokenizer(sentence)

    # tạo vector số hóa đúng chuẩn
    ids = (
        [vocab_en.stoi["<sos>"]] +
        [vocab_en.stoi.get(t, vocab_en.stoi["<unk>"]) for t in tokens] +
        [vocab_en.stoi["<eos>"]]
    )

    src = torch.tensor(ids).unsqueeze(1).to(device) # shape: [seq_len, 1]

    # get the real length (not include padding)
    src_lens = torch.tensor([len(ids)]).to(device) # shape: [1]

    with torch.no_grad():
        # encoder now returns encoder_outputs, hidden, cell
        encoder_outputs, hidden, cell = model.encoder(src, src_lens)

    # token đầu tiên đầu ra
    input_tok = torch.tensor([vocab_fr.stoi["<sos>"]]).to(device)
    outputs = []

    for _ in range(50):
        with torch.no_grad():
            # decoder signature: (input, hidden, cell, encoder_outputs)
            pred, hidden, cell, _ = model.decoder(input_tok, hidden, cell, encoder_outputs)

        top_id = pred.argmax(1).item()

        if top_id == vocab_fr.stoi["<eos>"]:
            break

        outputs.append(top_id)
        input_tok = torch.tensor([top_id]).to(device)

    return " ".join(vocab_fr.itos[i] for i in outputs)

# %% [markdown]
# # 7. TRAINING + VALIDATION + EARLY STOPPING

# %%
start_time = time.perf_counter()


input_dim = len(vocab_en)
output_dim = len(vocab_fr)
# print(input_dim, output_dim)

encoder = Encoder(vocab_size=input_dim, embed_dim=LSTM_EMBED_DIM_CURRENT, hidden_dim=LSTM_HIDDEN_DIM_CURRENT, num_layers=LSTM_NUM_LAYERS_CURRENT).to(device)  # 256, 512
decoder = Decoder(vocab_size=output_dim, embed_dim=LSTM_EMBED_DIM_CURRENT, hidden_dim=LSTM_HIDDEN_DIM_CURRENT, num_layers=LSTM_NUM_LAYERS_CURRENT).to(device)  # 256, 512

model = Seq2Seq(encoder, decoder).to(device)

# Ignore computing loss for PAD_IDX
criterion = nn.CrossEntropyLoss(ignore_index=PAD_IDX)
optimizer = optim.Adam(params=model.parameters(), lr=MODEL_LEARNING_RATE_CURRENT)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, factor=0.5, patience=1
)

def evaluate(model, loader):
    model.eval()
    total = 0
    # torch.no_grad(): remove old gradient
    with torch.no_grad():
        for src, trg, src_lens, trg_lens in loader:
            src, trg = src.to(device), trg.to(device)
            src_lens = src_lens.to(device)

            outputs = model(src, trg, src_lens, teacher_forcing=LSTM_TEACHER_FORCING_CURRENT)

            loss = criterion(outputs[1:].reshape(-1, outputs.size(-1)),
                             trg[1:].reshape(-1))

            total += loss.item()

    return total / len(loader)

best_val = float("inf")
best_state_dict = None
best_epoch = -1
wait = 0

val_loss_arr = []
train_loss_arr = []
val_bleu_arr = []

for epoch in range(MODEL_EPOCHS_CURRENT):
    model.train()
    total_loss = 0

    for src, trg, src_lens, trg_lens in tqdm(train_loader):
        src, trg = src.to(device), trg.to(device)
        src_lens = src_lens.to(device)

        optimizer.zero_grad()
        outputs = model(src, trg, src_lens) # Update

        loss = criterion(outputs[1:].reshape(-1, outputs.size(-1)),
                        trg[1:].reshape(-1))

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    train_loss = total_loss / len(train_loader)
    val_loss = evaluate(model, val_loader)

    train_loss_arr.append(train_loss)
    val_loss_arr.append(val_loss)

    # Compute validation BLEU each epoch (uses beam search for better quality)
    references = []
    hypotheses = []
    for en_tok, fr_tok in zip(val_en_tok, val_fr_tok):
        src_sentence = " ".join(en_tok)
        pred = translate_beam(src_sentence, beam_width=5)
        references.append([fr_tok])
        hypotheses.append(pred.split())
    val_bleu = corpus_bleu(references, hypotheses, weights=(0.25, 0.25, 0.25, 0.25))
    val_bleu_arr.append(val_bleu)

    scheduler.step(val_loss)
    print("Current LR:", optimizer.param_groups[0]["lr"])

    print(f"Epoch {epoch + 1} | Train = {train_loss:.4f} | Val = {val_loss:.4f} | Val BLEU = {val_bleu:.4f}\n")

    if val_loss < best_val:
        best_val = val_loss
        best_state_dict = model.state_dict()
        best_epoch = epoch
        wait = 0
        # torch.save(model.state_dict(), "best_model.pth")
    else:
        wait += 1
        if wait >= MODEL_EARLY_STOP_PATIENCE_CURRENT:
            print("\n[X] Early stopping triggered!\n")
            break

# Save the best model
torch.save(best_state_dict, "best_model.pth")
print(f"- Best model saved at epoch {best_epoch+1}, val_loss={best_val:.4f}")

end_time = time.perf_counter()
print(f"--- DONE ---!\n- Total training time: {end_time- start_time:.2f} seconds.")
# Out:
# 100%|██████████| 907/907 [02:36<00:00,  5.79it/s]
# Epoch 1 | Train = 4.1677 | Val = 3.0973 | Val BLEU = 0.2078
# 100%|██████████| 907/907 [02:19<00:00,  6.52it/s]
# Epoch 2 | Train = 2.6845 | Val = 2.2824 | Val BLEU = 0.3719
# 100%|██████████| 907/907 [02:17<00:00,  6.61it/s]
# Epoch 3 | Train = 2.0420 | Val = 1.9479 | Val BLEU = 0.4436
# 100%|██████████| 907/907 [02:21<00:00,  6.41it/s]
# Epoch 4 | Train = 1.6673 | Val = 1.9279 | Val BLEU = 0.4680
# 100%|██████████| 907/907 [02:18<00:00,  6.54it/s]
# Epoch 5 | Train = 1.4207 | Val = 1.8520 | Val BLEU = 0.4802
# 100%|██████████| 907/907 [02:18<00:00,  6.55it/s]
# Epoch 6 | Train = 1.2243 | Val = 1.7877 | Val BLEU = 0.4978
# 100%|██████████| 907/907 [02:17<00:00,  6.61it/s]
# Epoch 7 | Train = 1.0729 | Val = 1.8193 | Val BLEU = 0.5118
# 100%|██████████| 907/907 [02:17<00:00,  6.60it/s]
# Epoch 8 | Train = 0.9568 | Val = 1.7880 | Val BLEU = 0.5191
# 100%|██████████| 907/907 [02:19<00:00,  6.48it/s]
# Epoch 9 | Train = 0.8630 | Val = 1.7825 | Val BLEU = 0.5079
# 100%|██████████| 907/907 [02:52<00:00,  5.27it/s]
# Epoch 10 | Train = 0.7883 | Val = 1.8706 | Val BLEU = 0.5010
# 100%|██████████| 907/907 [02:21<00:00,  6.42it/s]
# Epoch 11 | Train = 0.7212 | Val = 1.8323 | Val BLEU = 0.5103
# 100%|██████████| 907/907 [02:38<00:00,  5.73it/s]
# Epoch 12 | Train = 0.6560 | Val = 1.8461 | Val BLEU = 0.5125
#
#
# [X] Early stopping triggered!
#
# - Best model saved at epoch 9, val_loss=1.7825
# --- DONE ---!
# - Total training time: 4838.68 seconds.

# %%
plt.figure(figsize=(10, 5))

# Plot both curves on the same chart
plt.plot(train_loss_arr, marker='o', label="Train Loss")
plt.plot(val_loss_arr, marker='s', label="Validation Loss")

# Mark best epoch for both
plt.scatter(best_epoch, train_loss_arr[best_epoch], color='red', s=100,
            label="Best Train Epoch")
plt.scatter(best_epoch, val_loss_arr[best_epoch], color='green', s=100,
            label="Best Val Epoch")

plt.title("Training vs Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# --- BLEU score plot (validation BLEU per epoch) ---
plt.figure(figsize=(10,5))
plt.plot(val_bleu_arr, marker='o', color='tab:blue', label='Val BLEU')
plt.title('Validation BLEU per Epoch')
plt.xlabel('Epoch')
plt.ylabel('BLEU')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # 8. TRANSLATE + BLEU SCORE

# %%
def translate_beam(sentence, beam_width=5, max_len=50):
    """
    Beam Search translation function.

    Args:
        sentence: input English sentence (str)
        beam_width: number of hypotheses to keep at each step (default=5)
        max_len: maximum translation length (default=50)

    Returns:
        Best translation (str) based on beam search
    """
    model.eval()

    # Tokenize input sentence
    tokens = en_tokenizer(sentence)

    # Create token indices with <sos> and <eos>
    ids = (
        [vocab_en.stoi["<sos>"]] +
        [vocab_en.stoi.get(t, vocab_en.stoi["<unk>"]) for t in tokens] +
        [vocab_en.stoi["<eos>"]]
    )

    src = torch.tensor(ids).unsqueeze(1).to(device)
    src_lens = torch.tensor([len(ids)]).to(device)

    with torch.no_grad():
        # Encoder forward pass
        encoder_outputs, hidden, cell = model.encoder(src, src_lens)

    # Initialize beam with <sos> token
    # Each item: (log_prob, [token_list], hidden_state, cell_state)
    beams = [(0.0, [vocab_fr.stoi["<sos>"]], hidden, cell)]
    completed_hypotheses = []

    # Beam search main loop
    for step in range(max_len):
        next_beams = []

        for log_prob, tokens_seq, h, c in beams:
            # If hypothesis already ended with <eos>, add to completed
            if tokens_seq[-1] == vocab_fr.stoi["<eos>"]:
                completed_hypotheses.append((log_prob, tokens_seq))
                continue

            # Decode next token
            input_tok = torch.tensor([tokens_seq[-1]]).to(device)

            with torch.no_grad():
                pred, h_new, c_new, _ = model.decoder(input_tok, h, c, encoder_outputs)
                log_probs = torch.log_softmax(pred, dim=1)  # [1, vocab_size]

            # Get top beam_width predictions
            top_log_probs, top_indices = torch.topk(log_probs[0], beam_width)

            # Create new hypotheses
            for token_log_prob, token_id in zip(top_log_probs, top_indices):
                new_log_prob = log_prob + token_log_prob.item()
                new_tokens = tokens_seq + [token_id.item()]
                next_beams.append((new_log_prob, new_tokens, h_new, c_new))

        # Keep only top beam_width hypotheses (sorted by log probability)
        next_beams.sort(key=lambda x: x[0], reverse=True)
        beams = next_beams[:beam_width]

        # Stop if all hypotheses have ended
        if not beams or all(tokens_seq[-1] == vocab_fr.stoi["<eos>"] for _, tokens_seq, _, _ in beams):
            break

    # Add remaining active hypotheses to completed
    for log_prob, tokens_seq, _, _ in beams:
        completed_hypotheses.append((log_prob, tokens_seq))

    # Select best hypothesis (highest log probability)
    if not completed_hypotheses:
        return ""

    completed_hypotheses.sort(key=lambda x: x[0], reverse=True)
    best_log_prob, best_tokens = completed_hypotheses[0]

    # Convert token indices to words (exclude <sos> and <eos>)
    output_tokens = [
        vocab_fr.itos[idx]
        for idx in best_tokens
        if idx != vocab_fr.stoi["<sos>"] and idx != vocab_fr.stoi["<eos>"]
    ]

    return " ".join(output_tokens)

# %%
def evaluate_bleu():
    references = []   # dạng: [[ref_tokens], [ref_tokens], ...]
    hypotheses = []   # dạng: [pred_tokens, pred_tokens, ...]

    for en, fr in zip(test_en_tok, test_fr_tok):
        # input cho model là chuỗi tiếng Anh
        pred = translate_beam(" ".join(en))

        # BLEU yêu cầu:
        #   - ref: list các câu tham chiếu → mỗi câu phải bọc trong 1 list
        #   - hyp: list các câu dự đoán tokenized
        references.append([fr])
        hypotheses.append(pred.split())

    score = corpus_bleu(
        references,
        hypotheses,
        weights=(0.25, 0.25, 0.25, 0.25)
    )
    return score


model.load_state_dict(torch.load("best_model.pth"))
bleu = evaluate_bleu()
print("Corpus BLEU on Test =", bleu)
# Out:
# Corpus BLEU on Test = 0.3170981470255453

# %%
# Số câu muốn thử
num_examples = 100

for i in range(num_examples):
    # Lấy câu gốc tiếng Anh
    en_sentence = " ".join(test_en_tok[i])

    # Dịch sang tiếng Pháp
    fr_pred = translate_beam(en_sentence)

    # Lấy câu tham chiếu tiếng Pháp
    fr_ref = " ".join(test_fr_tok[i])

    # In ra kết quả
    print(f"Example {i+1}")
    print("EN (Original) :", en_sentence)
    print("FR (Reference):", fr_ref)
    print("FR (Predicted):", fr_pred)
    print("-" * 60)
# Out:
# Example 1
# EN (Original) : a young man participates in a career while the subject who records it smiles .
# FR (Reference): un jeune homme participe à une course pendant que le sujet qui le filme sourit .
# FR (Predicted): un jeune homme participe à une foule tandis que le miroir qui dit sourit .
# ------------------------------------------------------------
# Example 2
# EN (Original) : the man is scratching the back of his neck while looking for a book in a book store .
# FR (Reference): l' homme se gratte l' arrière du cou tout en cherchant un livre dans une librairie .
# FR (Predicted): l' homme se la l' arrière de son cou tout en regardant un livre dans un magasin de coiffure .
# ------------------------------------------------------------
# Example 3
# EN (Original) : a person wearing goggles and a hat is sled riding .
# FR (Reference): une personne portant des lunettes de protection et un chapeau fait de la luge .
# FR (Predicted): une personne portant des lunettes et un chapeau fait du la luge .
# ------------------------------------------------------------
# Example 4
# EN (Original) : a girl in a pink coat and flowered goloshes sledding down a hill .
# FR (Reference): une fille avec une veste rose et des galoches à fleurs descend le long d' une colline en luge .
# FR (Predicted): une fille avec un manteau rose et un verre à fleurs faisant une pente .
# ------------------------------------------------------------
# Example 5
# EN (Original) : three girls are standing in front of a window of a building .
# FR (Reference): trois filles se tiennent devant la fenêtre d' un bâtiment .
# FR (Predicted): trois filles sont debout devant une fenêtre d' un bâtiment .
# ------------------------------------------------------------
# Example 6
# EN (Original) : two dog is playing with a same chump on their mouth
# FR (Reference): deux chiens jouent avec le même morceau de bois dans la bouche .
# FR (Predicted): deux chiens joue avec un comptoir de la gueule
# ------------------------------------------------------------
# Example 7
# EN (Original) : low angle view of people suspended from the swings of a carnival ride .
# FR (Reference): une vue en contre-plongée de personnes suspendues sur les balançoires d' un manège .
# FR (Predicted): des vue aérienne de monde monde à la balance d' une fête foraine .
# ------------------------------------------------------------
# Example 8
# EN (Original) : black and white photo of two people watching a beautiful painting
# FR (Reference): une photo en noir et blanc de deux personnes en train de regarder une magnifique toile .
# FR (Predicted): des photo noir et blanc sortant deux personnes qui regardent une scène .
# ------------------------------------------------------------
# Example 9
# EN (Original) : man dressed in black crosses the street screaming
# FR (Reference): un homme habillé en noir traverse la rue en criant .
# FR (Predicted): un homme habillé en noir traverse la rue
# ------------------------------------------------------------
# Example 10
# EN (Original) : a child sits on street on a busy street .
# FR (Reference): un enfant s' assied dans une rue très fréquentée .
# FR (Predicted): un enfant est assis dans la rue dans une rue très fréquentée .
# ------------------------------------------------------------
# Example 11
# EN (Original) : 15 large dogs playing   in a fenced yard beside a house .
# FR (Reference): 15 grands chiens jouent dans un jardin clôturé à côté d' une maison .
# FR (Predicted): des grands chiens noirs jouant dehors dans un jardin clôturé à côté d' une maison .
# ------------------------------------------------------------
# Example 12
# EN (Original) : a typical scene on a busy street in front of a red - painted building .
# FR (Reference): une scène typique dans une rue très fréquentée devant un bâtiment peint en rouge .
# FR (Predicted): un décor de scène sur une rue très fréquentée devant un bâtiment en
# ------------------------------------------------------------
# Example 13
# EN (Original) : a person walking one black dog on a leash while a yellow dog is unleashed .
# FR (Reference): une personne promène son chien noir en laisse alors que son labrador n' en a pas .
# FR (Predicted): une personne marchant un chien noir sur laisse tandis qu' un chien jaune est trouve .
# ------------------------------------------------------------
# Example 14
# EN (Original) : dog laying on outdoor wooden bench , with dog statue beside , yellow tennis ball laying on ground .
# FR (Reference): un chien est allongé sur un banc extérieur en bois , avec une statue de chien à côté de lui et il y a une balle de tennis jaune par terre .
# FR (Predicted): un chien couché sur un banc en bois en bois , avec un autre homme à la de jaune sur sur sol .
# ------------------------------------------------------------
# Example 15
# EN (Original) : a man is riding a bike with a child .
# FR (Reference): un homme fait du vélo avec un enfant .
# FR (Predicted): un homme fait du vélo avec un enfant .
# ------------------------------------------------------------
# Example 16
# EN (Original) : a big brown dog and small white dog playing with a frisbee in their mouths .
# FR (Reference): un grand chien brun et un petit chien blanc jouent avec un frisbee dans la bouche .
# FR (Predicted): un gros chien brun et un petit chien blanc jouant avec un frisbee dans leurs bouches .
# ------------------------------------------------------------
# Example 17
# EN (Original) : four children are sitting against a wall having a conversation while two adult men stare into space .
# FR (Reference): quatre enfants sont assis contre un mur en pleine conversation pendant que les deux hommes adultes regardent ailleurs .
# FR (Predicted): quatre enfants sont assis contre un mur , une conversation une conversation tandis que deux hommes regardent .
# ------------------------------------------------------------
# Example 18
# EN (Original) : three girls are sitting talking while the boys pose for the camera .
# FR (Reference): trois filles sont assises et en pleine discussion pendant que les garçons posent pour la caméra .
# FR (Predicted): trois filles sont assises à parler tandis que les garçons posent pour la photo .
# ------------------------------------------------------------
# Example 19
# EN (Original) : a lifeguard building is on the sand on a cloudy day .
# FR (Reference): la cabane d' un sauveteur sur le sable par une journée nuageuse .
# FR (Predicted): un bâtiment de bâtiment est sur le sable par une journée nuageuse .
# ------------------------------------------------------------
# Example 20
# EN (Original) : this is a young girl looking at a phone while the boy beside her is looking straight in to the camera .
# FR (Reference): on voit une jeune fille en train de regarder son téléphone avec un garçon à côté d' elle qui regarde directement vers la caméra .
# FR (Predicted): c' est une jeune fille regardant un téléphone tandis que le garçon à proximité d' elle regarde au caméra .
# ------------------------------------------------------------
# Example 21
# EN (Original) : a high view of people walking near a beach .
# FR (Reference): une vue en hauteur de personnes marchant près d' une plage .
# FR (Predicted): une vue aérienne de gens marchant près d' une plage .
# ------------------------------------------------------------
# Example 22
# EN (Original) : a dog is peeing on a dog statue in a garden .
# FR (Reference): un chien urine sur une statue de chien dans un jardin .
# FR (Predicted): un chien est trouve sur une statue , dans un jardin .
# ------------------------------------------------------------
# Example 23
# EN (Original) : a brown dog with a watering can on the ocico
# FR (Reference): un chien brun avec un arrosoir sur la pelouse .
# FR (Predicted): un chien brun avec un vêtement de la .
# ------------------------------------------------------------
# Example 24
# EN (Original) : an african american man playing guitar and singing in an urban setting .
# FR (Reference): un homme afro-américain joue de la guitare et chante dans un cadre urbain .
# FR (Predicted): un homme afro-américain jouant de la guitare et chantant dans un paysage urbain .
# ------------------------------------------------------------
# Example 25
# EN (Original) : a young girl dances on a stage as her blue skirt twirls .
# FR (Reference): une jeune fille danse sur une scène avec sa jupe bleue qui tournoie .
# FR (Predicted): une jeune fille danse sur une scène tandis que sa femme bleue .
# ------------------------------------------------------------
# Example 26
# EN (Original) : this image is of four women dancing in dresses in front of a group of people .
# FR (Reference): c' est l' image de quatre femmes qui dansent en robe devant un groupe de personnes .
# FR (Predicted): cette photo montre quatre femmes dansant en robes devant un groupe de personnes .
# ------------------------------------------------------------
# Example 27
# EN (Original) : a woman stands on a subway platform waiting for the train .
# FR (Reference): une femme se tient debout à un quai de métro à attendre le train .
# FR (Predicted): une femme est debout dans un quai de métro , attendant le train .
# ------------------------------------------------------------
# Example 28
# EN (Original) : two girls are wearing coats outside while eating ice cream .
# FR (Reference): deux filles portent une veste à l' extérieur en mangeant une glace .
# FR (Predicted): deux filles portent des manteaux dehors tout en mangeant des glace .
# ------------------------------------------------------------
# Example 29
# EN (Original) : black and white shot of a man picking up a newspaper on a city street
# FR (Reference): une photo en noir et blanc d' un homme qui prend un journal dans une rue .
# FR (Predicted): un photo de noir et blanc d' un homme ramassant un journal dans une rue en ville
# ------------------------------------------------------------
# Example 30
# EN (Original) : a crowd is standing outside and holding up their cellphones
# FR (Reference): une foule se tient debout à l' extérieur en tenant leur téléphone portable en hauteur .
# FR (Predicted): une foule est debout dehors , tenant leurs téléphones portables
# ------------------------------------------------------------
# Example 31
# EN (Original) : this image is of a dog running around a tree in a wooded area .
# FR (Reference): c' est l' image d' un chien qui court autour d' un arbre dans un terrain boisé .
# FR (Predicted): cette image d' un chien courant autour d' un arbre dans un espace boisé .
# ------------------------------------------------------------
# Example 32
# EN (Original) : this image is of a man and a woman walking on a beach in front of palm trees .
# FR (Reference): c' est l' image d' un homme et d' une femme qui marchent sur une plage devant des palmiers .
# FR (Predicted): cette image d' un homme et une femme marchant sur une plage devant des palmiers .
# ------------------------------------------------------------
# Example 33
# EN (Original) : young girl holding sign : " tenho em mim todos os sonhos do mundo " sitting on shoulders of man .
# FR (Reference): une petite fille tient une pancarte : " tenho em mim todos os sonhos do mundo " tout en étant assise sur les épaules d' un homme .
# FR (Predicted): une jeune fille tenant une pancarte représentant un pancarte " câlins gratuits , des vêtements traditionnels , des vêtements , de l' art sur un homme .
# ------------------------------------------------------------
# Example 34
# EN (Original) : a tan dog tugs on a hose from a vacuum cleaner .
# FR (Reference): un labrador tire sur le tuyau d' un aspirateur .
# FR (Predicted): un chien brun met un tuyau d' un tuyau d' aspirateur .
# ------------------------------------------------------------
# Example 35
# EN (Original) : a girl and a boy posing for a photo , in the background a lady sitting and several people standing
# FR (Reference): une fille et un garçon posent pour une photo , en arrière-plan il y a une femme assise et plusieurs personnes debout .
# FR (Predicted): une jeune fille et un garçon posant pour une photo , en arrière-plan assis et plusieurs personnes debout
# ------------------------------------------------------------
# Example 36
# EN (Original) : two people work on an elaborate sand sculpture that is shaped like a man .
# FR (Reference): deux personnes travaillent sur une sculpture de sable complexe qui a la forme d' un homme .
# FR (Predicted): deux personnes travaillent sur une sculpture de sable industriel qui ont un homme .
# ------------------------------------------------------------
# Example 37
# EN (Original) : black and white photo of a boy in the middle of a street
# FR (Reference): une photo en noir et blanc d' un garçon au beau milieu d' une rue .
# FR (Predicted): une photo en noir et blanc d' un garçon au milieu d' une rue
# ------------------------------------------------------------
# Example 38
# EN (Original) : the young girl in the white coat is clapping and clearly excited or happy .
# FR (Reference): la jeune fille avec une veste blanche applaudit et est clairement enthousiaste ou heureuse .
# FR (Predicted): la jeune fille en manteau blanc a sa main et crie .
# ------------------------------------------------------------
# Example 39
# EN (Original) : the dog is jumping after a toy held by the woman .
# FR (Reference): le chien saute pour attraper un jouet tenu par la femme .
# FR (Predicted): le chien saute après un jouet pour enfants par la femme .
# ------------------------------------------------------------
# Example 40
# EN (Original) : white dog with brown spots digging with his paws the sand
# FR (Reference): un chien blanc à tâches brunes creuse le sol avec ses pattes .
# FR (Predicted): un chien blanc avec des taches brunes creusant avec ses barres le sable
# ------------------------------------------------------------
# Example 41
# EN (Original) : a cat or dog trying to play the piano .
# FR (Reference): un chat ou un chien qui essaie de jouer du piano .
# FR (Predicted): un chat ou un chien essayant de jouer au piano .
# ------------------------------------------------------------
# Example 42
# EN (Original) : a child with a blue brimmed hat staring intently at something behind a fence .
# FR (Reference): un enfant avec un chapeau à bord bleu regarde fixement quelque chose derrière une barrière .
# FR (Predicted): un enfant avec un bonnet à bords bleu regardant attentivement quelque chose derrière une clôture .
# ------------------------------------------------------------
# Example 43
# EN (Original) : this image is of a little girl leaning against her parents bed while she 's looking at herself in the mirror .
# FR (Reference): c' est l' image d' une petite fille appuyée contre le lit de ses parents pendant qu' elle observe son reflet dans le miroir .
# FR (Predicted): cette image d' une petite fille se adossée contre son lit , tandis qu' elle se tient le le dans le miroir .
# ------------------------------------------------------------
# Example 44
# EN (Original) : a black girl hanging upside down with her little braids dragging the ground .
# FR (Reference): une fille à la peau mate à l' envers avec ses petites tresses qui touchent le sol .
# FR (Predicted): une fille noire finit la tête en bas avec son petit tirant tirant par sol .
# ------------------------------------------------------------
# Example 45
# EN (Original) : a black and white image of a woman in a coffee shop , and a reflection of a car in the window .
# FR (Reference): une image en noir et blanc d' une femme à un café , et le reflet d' une voiture dans la fenêtre .
# FR (Predicted): une photo noire et blanc d' une femme dans un café , et un reflet d' une voiture dans la fenêtre .
# ------------------------------------------------------------
# Example 46
# EN (Original) : black dog coming out of the beach with a toy on his trunk
# FR (Reference): un chien noir sort de la plage avec un jouet dans la bouche .
# FR (Predicted): un chien noir sortant hors de la plage avec un jouet sur son dos
# ------------------------------------------------------------
# Example 47
# EN (Original) : girls have suckers as they wear plastic over their costumes .
# FR (Reference): les filles ont des sucettes tout en portant du plastique par - dessus leurs costumes .
# FR (Predicted): des filles ont des signes tandis qu' elles ont en en au-dessus de leurs bouteilles .
# ------------------------------------------------------------
# Example 48
# EN (Original) : a man holds and speaks through a megaphone in the street
# FR (Reference): un homme parle à travers un mégaphone dans la rue .
# FR (Predicted): un homme tient et parle dans un mégaphone dans la rue
# ------------------------------------------------------------
# Example 49
# EN (Original) : six children of different races stand in front of a wooden fence
# FR (Reference): six enfants de race différente se tiennent debout devant une barrière en bois .
# FR (Predicted): six enfants d' différentes races se reposent devant une clôture en bois
# ------------------------------------------------------------
# Example 50
# EN (Original) : a child is dressed in all white with a white painted face .
# FR (Reference): un enfant est habillé tout en blanc avec de la peinture blanche sur le visage .
# FR (Predicted): un enfant est habillé tout en blanc avec le visage peint .
# ------------------------------------------------------------
# Example 51
# EN (Original) : a man in a yellow biking shirt and sunglasses walks along a street .
# FR (Reference): un homme avec un maillot jaune de cycliste et des lunettes de soleil marche dans la rue .
# FR (Predicted): un homme avec un t - shirt jaune et des lunettes de soleil marche le long d' une rue .
# ------------------------------------------------------------
# Example 52
# EN (Original) : a dog rests in the grass while its owner looks on .
# FR (Reference): un chien se repose dans l' herbe pendant que son propriétaire l' observe .
# FR (Predicted): un chien se repose dans l' herbe tandis que son propriétaire surveille .
# ------------------------------------------------------------
# Example 53
# EN (Original) : a woman laughs and hugs her dog as they sit on a grassy lawn together .
# FR (Reference): une femme rit et prend son chien dans les bras pendant qu' ils sont assis ensemble sur une pelouse bien verte .
# FR (Predicted): une femme rit et fait ses chien tandis qu' elle sont assis sur un pelouse ensemble .
# ------------------------------------------------------------
# Example 54
# EN (Original) : a blurry shot of someone walking through a terminal .
# FR (Reference): une photo floue de quelqu' un qui marche à travers un terminal .
# FR (Predicted): une photo floue de quelqu' un marchant dans une gare .
# ------------------------------------------------------------
# Example 55
# EN (Original) : a blond and white child with hands on waist
# FR (Reference): un enfant blond et blanc avec ses mains sur la taille .
# FR (Predicted): une jeune fille blonde et blanc avec les mains en l' air
# ------------------------------------------------------------
# Example 56
# EN (Original) : five white puppies huddled together with one licking the others snout .
# FR (Reference): cinq chiots blancs blottis ensemble avec un qui lèche le museau d' un autre .
# FR (Predicted): cinq agents blanches ensemble ensemble l' un d' entre elles se trouvent les autres .
# ------------------------------------------------------------
# Example 57
# EN (Original) : a puppy is content on top of a red train .
# FR (Reference): un chiot est content sur le toit d' un train rouge .
# FR (Predicted): un chiot est sur sommet d' un train rouge .
# ------------------------------------------------------------
# Example 58
# EN (Original) : black dog with front legs out with one yellow bandage on one leg .
# FR (Reference): un chien noir dont on voit les pattes avant , une portant un bandage jaune .
# FR (Predicted): un chien noir avec pattes pattes avec un pattes jaune sur une patte .
# ------------------------------------------------------------
# Example 59
# EN (Original) : a young girl closes her eyes to enjoy the music of a guitarist on a stage .
# FR (Reference): une jeune fille ferme les yeux pour profiter de la musique d' un guitariste sur scène .
# FR (Predicted): une jeune fille en train de courir les yeux vers la musique d' un guitariste sur une scène .
# ------------------------------------------------------------
# Example 60
# EN (Original) : black and white photo of a woman with her guitar accompanied by a friend
# FR (Reference): une photo en noir et blanc d' une femme avec sa guitare , accompagnée par un ami .
# FR (Predicted): une photo blanche et blanche sortant d' une femme avec sa guitare <unk> par un ami
# ------------------------------------------------------------
# Example 61
# EN (Original) : this is a woman looking at her phone and a man beside her drinking from a bottle .
# FR (Reference): c' est une femme qui regarde son téléphone et un homme à côté d' elle boit à la bouteille .
# FR (Predicted): cette est une femme regardant son téléphone et un homme à côté buvant dans une bouteille .
# ------------------------------------------------------------
# Example 62
# EN (Original) : black and white image of 3 men riding bicycles through a city street .
# FR (Reference): une image en noir et blanc de trois hommes roulant à vélo à travers une rue .
# FR (Predicted): des agents noires et blanc sont du trois hommes font du vélo dans une rue en ville .
# ------------------------------------------------------------
# Example 63
# EN (Original) : brown dog carries a bag on his back and inside a puppy
# FR (Reference): un chien brun porte un sac sur son dos et un chiot se trouve à l' intérieur .
# FR (Predicted): un chien marron porte un sac sur son dos et dans un chiot
# ------------------------------------------------------------
# Example 64
# EN (Original) : three young people with a guitar resting on top of a mountain
# FR (Reference): trois jeunes avec une guitare qui se reposent au sommet d' une montagne .
# FR (Predicted): trois jeunes hommes avec une guitare en terre au sommet d' une montagne
# ------------------------------------------------------------
# Example 65
# EN (Original) : a small girl and an old man do an acrobatic pirouette in front of a crowd in a street
# FR (Reference): une petite fille et un vieillard font une pirouette acrobatique devant une foule dans la rue .
# FR (Predicted): une petite fille et un homme plus âgé font des vêtements devant une foule dans une rue
# ------------------------------------------------------------
# Example 66
# EN (Original) : a tan dog splashes in a body of still water
# FR (Reference): un labrador s' éclabousse dans une étendue d' eau calme .
# FR (Predicted): un chien brun fait des éclaboussures dans une étendue d' eau
# ------------------------------------------------------------
# Example 67
# EN (Original) : a small dog giving a big jump to catch the ball
# FR (Reference): un petit chien saute très haut pour attraper la balle .
# FR (Predicted): un petit chien donnant un gros saut pour attraper la balle
# ------------------------------------------------------------
# Example 68
# EN (Original) : two men in a boat with a boy sitting on the bow holding a bottle .
# FR (Reference): deux hommes dans un bateau avec un garçon assis sur la proue tenant une bouteille .
# FR (Predicted): deux hommes dans un bateau avec un garçon assis sur le siège tenant une bouteille .
# ------------------------------------------------------------
# Example 69
# EN (Original) : black and white picture of a girl hanging upside down and giving thumbs up
# FR (Reference): une image en noir et blanc d' une fille suspendue à l' envers et qui donne des pouces vers le haut .
# FR (Predicted): une photo noir et blanc d' une fille accrochant la tête en bas et le pouce vers le haut
# ------------------------------------------------------------
# Example 70
# EN (Original) : a man with a beard is seen through a window holding a cup , while a man in the background reads a newspaper .
# FR (Reference): on peut voir un homme barbu à travers une fenêtre tenir un gobelet , pendant qu' un homme en arrière-plan lit un journal .
# FR (Predicted): un homme portant une barbe est à travers une fenêtre , tenant un gobelet , tandis qu' un homme en arrière-plan lit un journal .
# ------------------------------------------------------------
# Example 71
# EN (Original) : five young children making heart shapes with their hands .
# FR (Reference): 5 enfants qui font des cœurs avec leurs mains .
# FR (Predicted): cinq jeunes enfants font des fête avec leurs mains .
# ------------------------------------------------------------
# Example 72
# EN (Original) : a large white dog trying to get on a wooden deck while in the water of a lake .
# FR (Reference): un grand chien blanc essaie de monter sur une plateforme en bois tout en étant dans l' eau du lac .
# FR (Predicted): un grand chien blanc essayant d' attraper en bois en bois tout en étant dans l' eau d' un lac .
# ------------------------------------------------------------
# Example 73
# EN (Original) : black and white image of a little boy riding a big bicycle through the grass .
# FR (Reference): une image en noir et blanc d' un petit garçon qui roule avec un grand vélo à travers la verdure .
# FR (Predicted): un staffordshire noir et blanc d' un petit garçon chevauchant un gros vélo dans l' herbe .
# ------------------------------------------------------------
# Example 74
# EN (Original) : two young women pause next to a wall in order to look at a cell phone .
# FR (Reference): deux jeunes femmes s' arrêtent près d' un mur pour regarder leur téléphone .
# FR (Predicted): deux jeunes femmes se font près d' un mur dans une tente pour regarder un téléphone public .
# ------------------------------------------------------------
# Example 75
# EN (Original) : a crowd gathered in an urban setting uses umbrellas and plastic ponchos to protect themselves from the rain .
# FR (Reference): une foule rassemblée dans un milieu urbain utilise des parapluies et des ponchos en plastique pour se protéger de la pluie .
# FR (Predicted): une foule rassemblée dans un environnement urbain , avec des parapluies et des en plastique pour <unk> la pluie .
# ------------------------------------------------------------
# Example 76
# EN (Original) : a person jumps off of a high cliff into a river below .
# FR (Reference): une personne saute dans la rivière ci-dessous depuis une haute falaise .
# FR (Predicted): une personne saute d' une haute falaise dans une rivière en dessous .
# ------------------------------------------------------------
# Example 77
# EN (Original) : a person on a floating raft over the rapids of a river
# FR (Reference): une personne dans un canot pneumatique sur les rapides d' une rivière
# FR (Predicted): une personne sur un radeau flottant au-dessus des rapides d' une rivière
# ------------------------------------------------------------
# Example 78
# EN (Original) : two children jumping and running down a hill .
# FR (Reference): deux enfants sautent et descendent une colline en courant .
# FR (Predicted): deux enfants sautant et courant sur une colline .
# ------------------------------------------------------------
# Example 79
# EN (Original) : a young child with a red sweater is jumping rope on a city sidewalk .
# FR (Reference): un enfant avec un chandail rouge saute à la corde sur un trottoir .
# FR (Predicted): un jeune enfant avec un sweat rouge saute à la corde sur un trottoir en ville .
# ------------------------------------------------------------
# Example 80
# EN (Original) : person behind window sill offering liquor with person standing outside of window opening .
# FR (Reference): une personne derrière le rebord d' une fenêtre offre de la liqueur à une personne qui se trouve dehors , derrière l' ouverture de la fenêtre .
# FR (Predicted): une personne derrière une fenêtre , des vêtements et une personne debout devant une fenêtre ouverte .
# ------------------------------------------------------------
# Example 81
# EN (Original) : a large white dog standing on a wooden dock watching a duck swimming in a lake .
# FR (Reference): un grand chien blanc sur une plateforme en bois qui regarde un canard nager dans un lac .
# FR (Predicted): un gros chien blanc debout sur un quai en bois regardant un canard nager dans un lac .
# ------------------------------------------------------------
# Example 82
# EN (Original) : a dog in the water overlooking a sunset .
# FR (Reference): un chien dans l' eau qui regarde un coucher de soleil .
# FR (Predicted): un chien dans l' eau surplombant un coucher de soleil .
# ------------------------------------------------------------
# Example 83
# EN (Original) : a white dog chews on an empty plastic bottle while standing in a body of water
# FR (Reference): un chien blanc mâchouille une bouteille vide en plastique tout en se tenant dans une étendue d' eau .
# FR (Predicted): un chien blanc mâche un objet en plastique plastique , debout dans un plan d' eau
# ------------------------------------------------------------
# Example 84
# EN (Original) : a girl is sitting in the grass next to a white dog .
# FR (Reference): une fille est assise dans l' herbe à côté d' un chien blanc .
# FR (Predicted): une fille est assise dans l' herbe à côté d' un chien blanc .
# ------------------------------------------------------------
# Example 85
# EN (Original) : girl in unusual face mask with other people beside her .
# FR (Reference): une fille portant un masque facial inhabituel avec d' autres personnes à côté d' elle .
# FR (Predicted): une fille avec le visage peint avec d' autres personnes à côté d' elle .
# ------------------------------------------------------------
# Example 86
# EN (Original) : a woman holds her dog 's face in her face and prepares to kiss it .
# FR (Reference): une femme tient le visage de son chien entre ses mains et s' apprête à l' embrasser .
# FR (Predicted): une femme tient le visage d' son visage dans son visage et se prépare à lui .
# ------------------------------------------------------------
# Example 87
# EN (Original) : a group of police officers in argentina in black and white .
# FR (Reference): un groupe de policiers en argentine en noir et blanc .
# FR (Predicted): un groupe de policiers en en noir et blanc .
# ------------------------------------------------------------
# Example 88
# EN (Original) : someone jumping off of a large cliff into a mountain lake .
# FR (Reference): quelqu' un saute dans un lac de montagne depuis une grande falaise .
# FR (Predicted): quelqu' un sautant d' une grande falaise dans un lac .
# ------------------------------------------------------------
# Example 89
# EN (Original) : a painter is painting a larger version of a picture .
# FR (Reference): un peintre en plein travail sur une version plus large d' une image .
# FR (Predicted): un peintre peint un gros bâton dans une photo .
# ------------------------------------------------------------
# Example 90
# EN (Original) : a man and a woman look at flyers stuck in a glass .
# FR (Reference): un homme et une femme qui regardent des flyers collés sur une vitre .
# FR (Predicted): un homme et une femme regardent des produits dans un verre .
# ------------------------------------------------------------
# Example 91
# EN (Original) : a beach house next to sand and a group of people in the background of a black and white shot .
# FR (Reference): une maison de plage à côté du sable et un groupe de personnes au fond d' une image en noir et blanc .
# FR (Predicted): une une plage près de sable et un groupe de personnes en arrière-plan et un groupe de personnes noire .
# ------------------------------------------------------------
# Example 92
# EN (Original) : a child wears a pair of goggles in front of a uhaul
# FR (Reference): un enfant porte des lunettes de protection devant un camion u - haul .
# FR (Predicted): un enfant porte un paire de lunettes dans un verre
# ------------------------------------------------------------
# Example 93
# EN (Original) : an old woman in a heavy jacket is eating of a plate on her lap .
# FR (Reference): une vieille femme portant une grosse veste est en train de manger ce qu' il y a sur un plateau placé sur ses genoux .
# FR (Predicted): une vieille femme en veste épais mange mange une assiette sur ses genoux .
# ------------------------------------------------------------
# Example 94
# EN (Original) : a person is beginning to descend the stairs to the subway in a foreign country .
# FR (Reference): une personne commence à descendre les escaliers qui vont l' amener au métro dans un pays étranger .
# FR (Predicted): une personne répare prépare à faire du escaliers dans un pays étranger .
# ------------------------------------------------------------
# Example 95
# EN (Original) : the girl is at a playground wearing a colorful dress .
# FR (Reference): la fille est sur une aire de jeux habillée d' une robe colorée .
# FR (Predicted): la jeune fille est un d' une robe colorée .
# ------------------------------------------------------------
# Example 96
# EN (Original) : a person with arms extended wears a green and yellow parrot costume .
# FR (Reference): une personne qui tend les bras et porte un costume de perroquet vert et jaune .
# FR (Predicted): une personne avec les bras dessous un costume jaune et jaune .
# ------------------------------------------------------------
# Example 97
# EN (Original) : a man is walking by himself in front of a church .
# FR (Reference): un homme marche tout seul devant une église .
# FR (Predicted): un homme passe en passant devant une église .
# ------------------------------------------------------------
# Example 98
# EN (Original) : a man plays a guitar and drinks a small coffee .
# FR (Reference): un homme joue de la guitare et boit un petit café .
# FR (Predicted): un homme joue de la guitare et boit un petit café .
# ------------------------------------------------------------
# Example 99
# EN (Original) : a man going down the stairs of the subway of the city
# FR (Reference): un homme descend les escaliers du métro de la ville .
# FR (Predicted): un homme descendant les escaliers de métro ville
# ------------------------------------------------------------
# Example 100
# EN (Original) : a man walks dow a dirt path on the side of the road .
# FR (Reference): un homme descend le long d' une route sale .
# FR (Predicted): un homme marche avec un chemin de terre au bord de la route .
# ------------------------------------------------------------

# %%
# === COMPARISON: GREEDY vs BEAM SEARCH ===
print("\n" + "="*80)
print("GREEDY DECODING vs BEAM SEARCH TRANSLATION COMPARISON")
print("="*80 + "\n")

num_examples = 100

beam_widths = [3, 4, 5]

for idx in range(num_examples):
    en_sentence = " ".join(test_en_tok[idx])
    fr_ref = " ".join(test_fr_tok[idx])

    # Greedy translation
    fr_greedy = translate(en_sentence)

    # Beam search with different widths
    beam_translations = {}
    for bw in beam_widths:
        beam_translations[bw] = translate_beam(en_sentence, beam_width=bw)

    print(f"Example {idx + 1}:")
    print(f"  EN (Original) : {en_sentence}")
    print(f"  FR (Reference): {fr_ref}")
    print(f"  FR (Greedy)   : {fr_greedy}")
    for bw in beam_widths:
        print(f"  FR (Beam-{bw:2d})  : {beam_translations[bw]}")
    print("-" * 80)
# Out:
# ================================================================================
# GREEDY DECODING vs BEAM SEARCH TRANSLATION COMPARISON
# ================================================================================
#
# Example 1:
#   EN (Original) : a young man participates in a career while the subject who records it smiles .
#   FR (Reference): un jeune homme participe à une course pendant que le sujet qui le filme sourit .
#   FR (Greedy)   : un jeune homme participe à une foule tandis que le <unk> qui est en train de sourire .
#   FR (Beam- 3)  : un jeune homme participe à une foule tandis que le miroir qui dit sourit .
#   FR (Beam- 4)  : un jeune homme participe à une foule tandis que le miroir qui dit sourit .
#   FR (Beam- 5)  : un jeune homme participe à une foule tandis que le miroir qui dit sourit .
# --------------------------------------------------------------------------------
# Example 2:
#   EN (Original) : the man is scratching the back of his neck while looking for a book in a book store .
#   FR (Reference): l' homme se gratte l' arrière du cou tout en cherchant un livre dans une librairie .
#   FR (Greedy)   : l' homme se la l' arrière de son cou tout en regardant un livre dans un magasin de un .
#   FR (Beam- 3)  : l' homme se la l' arrière de son cou tout en regardant un livre dans un magasin de .
#   FR (Beam- 4)  : l' homme se la l' arrière de son cou tout en regardant un livre dans un magasin de coiffure .
#   FR (Beam- 5)  : l' homme se la l' arrière de son cou tout en regardant un livre dans un magasin de coiffure .
# --------------------------------------------------------------------------------
# Example 3:
#   EN (Original) : a person wearing goggles and a hat is sled riding .
#   FR (Reference): une personne portant des lunettes de protection et un chapeau fait de la luge .
#   FR (Greedy)   : une personne portant des lunettes et un chapeau de pilote .
#   FR (Beam- 3)  : une personne portant des lunettes et un chapeau fait du la luge .
#   FR (Beam- 4)  : une personne portant des lunettes et un chapeau fait du la luge .
#   FR (Beam- 5)  : une personne portant des lunettes et un chapeau fait du la luge .
# --------------------------------------------------------------------------------
# Example 4:
#   EN (Original) : a girl in a pink coat and flowered goloshes sledding down a hill .
#   FR (Reference): une fille avec une veste rose et des galoches à fleurs descend le long d' une colline en luge .
#   FR (Greedy)   : une fille avec un manteau rose et une lampe de dessin en train de descendre une pente .
#   FR (Beam- 3)  : une jeune fille avec un manteau rose et un sac à fleurs regardant une pente .
#   FR (Beam- 4)  : une fille avec un manteau rose et un verre à fleurs faisant une pente .
#   FR (Beam- 5)  : une fille avec un manteau rose et un verre à fleurs faisant une pente .
# --------------------------------------------------------------------------------
# Example 5:
#   EN (Original) : three girls are standing in front of a window of a building .
#   FR (Reference): trois filles se tiennent devant la fenêtre d' un bâtiment .
#   FR (Greedy)   : trois filles sont debout devant une fenêtre d' un bâtiment .
#   FR (Beam- 3)  : trois filles sont debout devant une fenêtre d' un bâtiment .
#   FR (Beam- 4)  : trois filles sont debout devant une fenêtre d' un bâtiment .
#   FR (Beam- 5)  : trois filles sont debout devant une fenêtre d' un bâtiment .
# --------------------------------------------------------------------------------
# Example 6:
#   EN (Original) : two dog is playing with a same chump on their mouth
#   FR (Reference): deux chiens jouent avec le même morceau de bois dans la bouche .
#   FR (Greedy)   : deux chiens joue avec un comptoir de la gueule
#   FR (Beam- 3)  : deux chiens joue avec un comptoir de la gueule
#   FR (Beam- 4)  : deux chiens joue avec un comptoir de la gueule
#   FR (Beam- 5)  : deux chiens joue avec un comptoir de la gueule
# --------------------------------------------------------------------------------
# Example 7:
#   EN (Original) : low angle view of people suspended from the swings of a carnival ride .
#   FR (Reference): une vue en contre-plongée de personnes suspendues sur les balançoires d' un manège .
#   FR (Greedy)   : <unk> cycliste <unk> personnes personnes suspendu à des structure de une attraction de fête foraine .
#   FR (Beam- 3)  : des vue aérienne de monde monde à la balance d' une fête foraine .
#   FR (Beam- 4)  : des vue aérienne de monde monde à la balance d' une fête foraine .
#   FR (Beam- 5)  : des vue aérienne de monde monde à la balance d' une fête foraine .
# --------------------------------------------------------------------------------
# Example 8:
#   EN (Original) : black and white photo of two people watching a beautiful painting
#   FR (Reference): une photo en noir et blanc de deux personnes en train de regarder une magnifique toile .
#   FR (Greedy)   : des photo et et blancs sortant deux personnes qui regardent une bel train de
#   FR (Beam- 3)  : des photo noir et blanc sortant deux personnes qui regardent une peinture en
#   FR (Beam- 4)  : des photo noir et blanc sortant deux personnes qui regardent une scène .
#   FR (Beam- 5)  : des photo noir et blanc sortant deux personnes qui regardent une scène .
# --------------------------------------------------------------------------------
# Example 9:
#   EN (Original) : man dressed in black crosses the street screaming
#   FR (Reference): un homme habillé en noir traverse la rue en criant .
#   FR (Greedy)   : un homme habillé en noir traverse la rue
#   FR (Beam- 3)  : un homme habillé en noir traverse la rue
#   FR (Beam- 4)  : un homme habillé en noir traverse la rue
#   FR (Beam- 5)  : un homme habillé en noir traverse la rue
# --------------------------------------------------------------------------------
# Example 10:
#   EN (Original) : a child sits on street on a busy street .
#   FR (Reference): un enfant s' assied dans une rue très fréquentée .
#   FR (Greedy)   : un enfant est assis dans la rue très fréquentée .
#   FR (Beam- 3)  : un enfant est assis dans la rue dans une rue très fréquentée .
#   FR (Beam- 4)  : un enfant est assis dans la rue dans une rue très fréquentée .
#   FR (Beam- 5)  : un enfant est assis dans la rue dans une rue très fréquentée .
# --------------------------------------------------------------------------------
# Example 11:
#   EN (Original) : 15 large dogs playing   in a fenced yard beside a house .
#   FR (Reference): 15 grands chiens jouent dans un jardin clôturé à côté d' une maison .
#   FR (Greedy)   : des grands chiens noirs jouant ensemble , dans un jardin clôturé à une maison .
#   FR (Beam- 3)  : des grands chiens noirs jouant dehors dans un jardin clôturé à côté d' une maison .
#   FR (Beam- 4)  : des grands chiens noirs jouant dehors dans un jardin clôturé à côté d' une maison .
#   FR (Beam- 5)  : des grands chiens noirs jouant dehors dans un jardin clôturé à côté d' une maison .
# --------------------------------------------------------------------------------
# Example 12:
#   EN (Original) : a typical scene on a busy street in front of a red - painted building .
#   FR (Reference): une scène typique dans une rue très fréquentée devant un bâtiment peint en rouge .
#   FR (Greedy)   : un décor de scène sur une rue très fréquentée devant un bâtiment en bâtiment rouge .
#   FR (Beam- 3)  : un décor de friandises sur une rue très fréquentée devant un bâtiment en rouge .
#   FR (Beam- 4)  : un décor de scène sur une rue très fréquentée devant un bâtiment en
#   FR (Beam- 5)  : un décor de scène sur une rue très fréquentée devant un bâtiment en
# --------------------------------------------------------------------------------
# Example 13:
#   EN (Original) : a person walking one black dog on a leash while a yellow dog is unleashed .
#   FR (Reference): une personne promène son chien noir en laisse alors que son labrador n' en a pas .
#   FR (Greedy)   : une personne marchant un chien noir laisse laisse tandis qu' un chien jaune est en train de manger .
#   FR (Beam- 3)  : une personne marchant dans un chien noir laisse une laisse jaune est trouve .
#   FR (Beam- 4)  : une personne marchant un chien noir sur laisse tandis qu' un chien jaune est trouve .
#   FR (Beam- 5)  : une personne marchant un chien noir sur laisse tandis qu' un chien jaune est trouve .
# --------------------------------------------------------------------------------
# Example 14:
#   EN (Original) : dog laying on outdoor wooden bench , with dog statue beside , yellow tennis ball laying on ground .
#   FR (Reference): un chien est allongé sur un banc extérieur en bois , avec une statue de chien à côté de lui et il y a une balle de tennis jaune par terre .
#   FR (Greedy)   : un chien couché sur un banc en bois en train de jouer , avec un autre homme à la de jaune sur sur sol .
#   FR (Beam- 3)  : un chien couché sur un banc en bois en bois , avec un autre homme à côté de la balle jaune sur le sol .
#   FR (Beam- 4)  : un chien couché sur un banc en bois en bois , avec un autre homme à la de jaune sur sur sol .
#   FR (Beam- 5)  : un chien couché sur un banc en bois en bois , avec un autre homme à la de jaune sur sur sol .
# --------------------------------------------------------------------------------
# Example 15:
#   EN (Original) : a man is riding a bike with a child .
#   FR (Reference): un homme fait du vélo avec un enfant .
#   FR (Greedy)   : un homme fait du vélo avec un enfant .
#   FR (Beam- 3)  : un homme fait du vélo avec un enfant .
#   FR (Beam- 4)  : un homme fait du vélo avec un enfant .
#   FR (Beam- 5)  : un homme fait du vélo avec un enfant .
# --------------------------------------------------------------------------------
# Example 16:
#   EN (Original) : a big brown dog and small white dog playing with a frisbee in their mouths .
#   FR (Reference): un grand chien brun et un petit chien blanc jouent avec un frisbee dans la bouche .
#   FR (Greedy)   : un gros chien brun et un petit chien blanc jouant avec un frisbee dans leurs bouches .
#   FR (Beam- 3)  : un gros chien brun et un petit chien blanc jouant avec un frisbee dans leurs bouches .
#   FR (Beam- 4)  : un gros chien brun et un petit chien blanc jouant avec un frisbee dans leurs bouches .
#   FR (Beam- 5)  : un gros chien brun et un petit chien blanc jouant avec un frisbee dans leurs bouches .
# --------------------------------------------------------------------------------
# Example 17:
#   EN (Original) : four children are sitting against a wall having a conversation while two adult men stare into space .
#   FR (Reference): quatre enfants sont assis contre un mur en pleine conversation pendant que les deux hommes adultes regardent ailleurs .
#   FR (Greedy)   : quatre enfants sont assis contre un mur , une conversation une conversation tandis que deux hommes regardent dans un espace .
#   FR (Beam- 3)  : quatre enfants sont assis contre un mur , une conversation une conversation tandis que deux hommes regardent .
#   FR (Beam- 4)  : quatre enfants sont assis contre un mur , une conversation une conversation tandis que deux hommes regardent .
#   FR (Beam- 5)  : quatre enfants sont assis contre un mur , une conversation une conversation tandis que deux hommes regardent .
# --------------------------------------------------------------------------------
# Example 18:
#   EN (Original) : three girls are sitting talking while the boys pose for the camera .
#   FR (Reference): trois filles sont assises et en pleine discussion pendant que les garçons posent pour la caméra .
#   FR (Greedy)   : trois filles sont assises , tandis que les garçons posent pour la photo .
#   FR (Beam- 3)  : trois filles sont assises à parler tandis que les garçons posent pour la photo .
#   FR (Beam- 4)  : trois filles sont assises à parler tandis que les garçons posent pour la photo .
#   FR (Beam- 5)  : trois filles sont assises à parler tandis que les garçons posent pour la photo .
# --------------------------------------------------------------------------------
# Example 19:
#   EN (Original) : a lifeguard building is on the sand on a cloudy day .
#   FR (Reference): la cabane d' un sauveteur sur le sable par une journée nuageuse .
#   FR (Greedy)   : un bâtiment de bâtiment est sur le sable par une journée nuageuse .
#   FR (Beam- 3)  : un bâtiment de bâtiment est sur le sable par une journée nuageuse .
#   FR (Beam- 4)  : un bâtiment de bâtiment est sur le sable par une journée nuageuse .
#   FR (Beam- 5)  : un bâtiment de bâtiment est sur le sable par une journée nuageuse .
# --------------------------------------------------------------------------------
# Example 20:
#   EN (Original) : this is a young girl looking at a phone while the boy beside her is looking straight in to the camera .
#   FR (Reference): on voit une jeune fille en train de regarder son téléphone avec un garçon à côté d' elle qui regarde directement vers la caméra .
#   FR (Greedy)   : c' est une jeune fille regardant un téléphone tandis que le garçon à côté d' elle regarde regarde dans l' objectif .
#   FR (Beam- 3)  : c' est une jeune fille regardant un téléphone tandis que le garçon à proximité d' elle regarde au caméra .
#   FR (Beam- 4)  : c' est une jeune fille regardant un téléphone tandis que le garçon à proximité d' elle regarde au caméra .
#   FR (Beam- 5)  : c' est une jeune fille regardant un téléphone tandis que le garçon à proximité d' elle regarde au caméra .
# --------------------------------------------------------------------------------
# Example 21:
#   EN (Original) : a high view of people walking near a beach .
#   FR (Reference): une vue en hauteur de personnes marchant près d' une plage .
#   FR (Greedy)   : une vue aérienne de gens marchant près d' une plage .
#   FR (Beam- 3)  : une vue aérienne de gens marchant près d' une plage .
#   FR (Beam- 4)  : une vue aérienne de gens marchant près d' une plage .
#   FR (Beam- 5)  : une vue aérienne de gens marchant près d' une plage .
# --------------------------------------------------------------------------------
# Example 22:
#   EN (Original) : a dog is peeing on a dog statue in a garden .
#   FR (Reference): un chien urine sur une statue de chien dans un jardin .
#   FR (Greedy)   : un chien est trouve sur une statue de dans un jardin .
#   FR (Beam- 3)  : un chien est en train de se reposer dans une statue dans un jardin .
#   FR (Beam- 4)  : un chien est trouve sur une statue , dans un jardin .
#   FR (Beam- 5)  : un chien est trouve sur une statue , dans un jardin .
# --------------------------------------------------------------------------------
# Example 23:
#   EN (Original) : a brown dog with a watering can on the ocico
#   FR (Reference): un chien brun avec un arrosoir sur la pelouse .
#   FR (Greedy)   : un chien marron avec un fond de la .
#   FR (Beam- 3)  : un chien brun avec un vêtement de la .
#   FR (Beam- 4)  : un chien brun avec un vêtement de la .
#   FR (Beam- 5)  : un chien brun avec un vêtement de la .
# --------------------------------------------------------------------------------
# Example 24:
#   EN (Original) : an african american man playing guitar and singing in an urban setting .
#   FR (Reference): un homme afro-américain joue de la guitare et chante dans un cadre urbain .
#   FR (Greedy)   : un homme afro-américain jouant de la guitare et chantant dans un paysage urbain .
#   FR (Beam- 3)  : un homme afro-américain jouant de la guitare et chantant dans un paysage urbain .
#   FR (Beam- 4)  : un homme afro-américain jouant de la guitare et chantant dans un paysage urbain .
#   FR (Beam- 5)  : un homme afro-américain jouant de la guitare et chantant dans un paysage urbain .
# --------------------------------------------------------------------------------
# Example 25:
#   EN (Original) : a young girl dances on a stage as her blue skirt twirls .
#   FR (Reference): une jeune fille danse sur une scène avec sa jupe bleue qui tournoie .
#   FR (Greedy)   : une jeune fille danse sur une scène tandis que son une est <unk> .
#   FR (Beam- 3)  : une jeune fille danse sur une scène tandis que sa femme bleue .
#   FR (Beam- 4)  : une jeune fille danse sur une scène tandis que sa femme bleue .
#   FR (Beam- 5)  : une jeune fille danse sur une scène tandis que sa femme bleue .
# --------------------------------------------------------------------------------
# Example 26:
#   EN (Original) : this image is of four women dancing in dresses in front of a group of people .
#   FR (Reference): c' est l' image de quatre femmes qui dansent en robe devant un groupe de personnes .
#   FR (Greedy)   : cette photo de quatre femmes dansant en robes devant un groupe de personnes .
#   FR (Beam- 3)  : cette photo montre quatre femmes dansant en robes devant un groupe de personnes .
#   FR (Beam- 4)  : cette photo montre quatre femmes dansant en robes devant un groupe de personnes .
#   FR (Beam- 5)  : cette photo montre quatre femmes dansant en robes devant un groupe de personnes .
# --------------------------------------------------------------------------------
# Example 27:
#   EN (Original) : a woman stands on a subway platform waiting for the train .
#   FR (Reference): une femme se tient debout à un quai de métro à attendre le train .
#   FR (Greedy)   : une femme est debout dans un quai de métro , attendant le train .
#   FR (Beam- 3)  : une femme est debout dans un quai de métro , attendant le train .
#   FR (Beam- 4)  : une femme est debout dans un quai de métro , attendant le train .
#   FR (Beam- 5)  : une femme est debout dans un quai de métro , attendant le train .
# --------------------------------------------------------------------------------
# Example 28:
#   EN (Original) : two girls are wearing coats outside while eating ice cream .
#   FR (Reference): deux filles portent une veste à l' extérieur en mangeant une glace .
#   FR (Greedy)   : deux filles portent des manteaux dehors tandis en étant une glace .
#   FR (Beam- 3)  : deux filles portent des manteaux dehors tout en mangeant des glace .
#   FR (Beam- 4)  : deux filles portent des manteaux dehors tout en mangeant des glace .
#   FR (Beam- 5)  : deux filles portent des manteaux dehors tout en mangeant des glace .
# --------------------------------------------------------------------------------
# Example 29:
#   EN (Original) : black and white shot of a man picking up a newspaper on a city street
#   FR (Reference): une photo en noir et blanc d' un homme qui prend un journal dans une rue .
#   FR (Greedy)   : des agents de noir et blanc d' un homme ramassant un journal dans une rue en ville
#   FR (Beam- 3)  : un photo de noir et blanc d' un homme ramassant un journal dans une rue en ville
#   FR (Beam- 4)  : un photo de noir et blanc d' un homme ramassant un journal dans une rue en ville
#   FR (Beam- 5)  : un photo de noir et blanc d' un homme ramassant un journal dans une rue en ville
# --------------------------------------------------------------------------------
# Example 30:
#   EN (Original) : a crowd is standing outside and holding up their cellphones
#   FR (Reference): une foule se tient debout à l' extérieur en tenant leur téléphone portable en hauteur .
#   FR (Greedy)   : une foule est debout dehors , tenant leurs téléphones portables
#   FR (Beam- 3)  : une foule est debout dehors , tenant leurs téléphones portables
#   FR (Beam- 4)  : une foule est debout dehors , tenant leurs téléphones portables
#   FR (Beam- 5)  : une foule est debout dehors , tenant leurs téléphones portables
# --------------------------------------------------------------------------------
# Example 31:
#   EN (Original) : this image is of a dog running around a tree in a wooded area .
#   FR (Reference): c' est l' image d' un chien qui court autour d' un arbre dans un terrain boisé .
#   FR (Greedy)   : cette image d' un chien qui qui autour d' un arbre dans un espace boisé .
#   FR (Beam- 3)  : cette image d' un chien courant autour d' un arbre dans un espace boisé .
#   FR (Beam- 4)  : cette image d' un chien courant autour d' un arbre dans un espace boisé .
#   FR (Beam- 5)  : cette image d' un chien courant autour d' un arbre dans un espace boisé .
# --------------------------------------------------------------------------------
# Example 32:
#   EN (Original) : this image is of a man and a woman walking on a beach in front of palm trees .
#   FR (Reference): c' est l' image d' un homme et d' une femme qui marchent sur une plage devant des palmiers .
#   FR (Greedy)   : cette image d' un homme et une femme marchant sur une plage devant des palmiers .
#   FR (Beam- 3)  : cette image d' un homme et une femme marchant sur une plage devant des palmiers .
#   FR (Beam- 4)  : cette image d' un homme et une femme marchant sur une plage devant des palmiers .
#   FR (Beam- 5)  : cette image d' un homme et une femme marchant sur une plage devant des palmiers .
# --------------------------------------------------------------------------------
# Example 33:
#   EN (Original) : young girl holding sign : " tenho em mim todos os sonhos do mundo " sitting on shoulders of man .
#   FR (Reference): une petite fille tient une pancarte : " tenho em mim todos os sonhos do mundo " tout en étant assise sur les épaules d' un homme .
#   FR (Greedy)   : une jeune fille tenant une pancarte proposant une pancarte " câlins gratuits , des vêtements traditionnels , de vêtements , de l' art sur un homme .
#   FR (Beam- 3)  : une jeune fille tenant une pancarte proposant une pancarte " câlins gratuits , des vêtements traditionnels , de vêtements , de l' art sur un homme .
#   FR (Beam- 4)  : une jeune fille tenant une pancarte représentant un pancarte " câlins gratuits , des vêtements traditionnels , des vêtements , de l' homme sur des <unk> .
#   FR (Beam- 5)  : une jeune fille tenant une pancarte représentant un pancarte " câlins gratuits , des vêtements traditionnels , des vêtements , de l' art sur un homme .
# --------------------------------------------------------------------------------
# Example 34:
#   EN (Original) : a tan dog tugs on a hose from a vacuum cleaner .
#   FR (Reference): un labrador tire sur le tuyau d' un aspirateur .
#   FR (Greedy)   : un chien brun met un tuyau d' un tuyau d' aspirateur .
#   FR (Beam- 3)  : un chien brun met un tuyau d' un tuyau d' aspirateur .
#   FR (Beam- 4)  : un chien brun met un tuyau d' un tuyau d' aspirateur .
#   FR (Beam- 5)  : un chien brun met un tuyau d' un tuyau d' aspirateur .
# --------------------------------------------------------------------------------
# Example 35:
#   EN (Original) : a girl and a boy posing for a photo , in the background a lady sitting and several people standing
#   FR (Reference): une fille et un garçon posent pour une photo , en arrière-plan il y a une femme assise et plusieurs personnes debout .
#   FR (Greedy)   : une fille et un garçon posant pour une photo , en arrière-plan , une dame assise et plusieurs personnes debout
#   FR (Beam- 3)  : une jeune fille et un garçon posant pour une photo , en arrière-plan , une femme assise et plusieurs personnes debout
#   FR (Beam- 4)  : une jeune fille et un garçon posant pour une photo , en arrière-plan , une femme assise et plusieurs personnes debout
#   FR (Beam- 5)  : une jeune fille et un garçon posant pour une photo , en arrière-plan assis et plusieurs personnes debout
# --------------------------------------------------------------------------------
# Example 36:
#   EN (Original) : two people work on an elaborate sand sculpture that is shaped like a man .
#   FR (Reference): deux personnes travaillent sur une sculpture de sable complexe qui a la forme d' un homme .
#   FR (Greedy)   : deux personnes travaillent sur une sculpture de sable industriel qui se pas un homme .
#   FR (Beam- 3)  : deux personnes travaillent sur une sculpture de sable industriel qui est en place un homme .
#   FR (Beam- 4)  : deux personnes travaillent sur une sculpture de sable industriel qui ont un homme .
#   FR (Beam- 5)  : deux personnes travaillent sur une sculpture de sable industriel qui ont un homme .
# --------------------------------------------------------------------------------
# Example 37:
#   EN (Original) : black and white photo of a boy in the middle of a street
#   FR (Reference): une photo en noir et blanc d' un garçon au beau milieu d' une rue .
#   FR (Greedy)   : une photo de noir et blanc d' un garçon au milieu d' une rue
#   FR (Beam- 3)  : une photo en noir et blanc d' un garçon au milieu d' une rue
#   FR (Beam- 4)  : une photo en noir et blanc d' un garçon au milieu d' une rue
#   FR (Beam- 5)  : une photo en noir et blanc d' un garçon au milieu d' une rue
# --------------------------------------------------------------------------------
# Example 38:
#   EN (Original) : the young girl in the white coat is clapping and clearly excited or happy .
#   FR (Reference): la jeune fille avec une veste blanche applaudit et est clairement enthousiaste ou heureuse .
#   FR (Greedy)   : la jeune fille en manteau blanc a des <unk> et des gens ou ou .
#   FR (Beam- 3)  : la jeune fille en manteau blanc a des <unk> et des gens ou ou .
#   FR (Beam- 4)  : la jeune fille en manteau blanc a sa main et crie .
#   FR (Beam- 5)  : la jeune fille en manteau blanc a sa main et crie .
# --------------------------------------------------------------------------------
# Example 39:
#   EN (Original) : the dog is jumping after a toy held by the woman .
#   FR (Reference): le chien saute pour attraper un jouet tenu par la femme .
#   FR (Greedy)   : le chien saute pour un jouet pour enfants à la femme .
#   FR (Beam- 3)  : le chien saute après un jouet pour enfants par la femme .
#   FR (Beam- 4)  : le chien saute après un jouet pour enfants par la femme .
#   FR (Beam- 5)  : le chien saute après un jouet pour enfants par la femme .
# --------------------------------------------------------------------------------
# Example 40:
#   EN (Original) : white dog with brown spots digging with his paws the sand
#   FR (Reference): un chien blanc à tâches brunes creuse le sol avec ses pattes .
#   FR (Greedy)   : un chien blanc avec des taches brunes creusant avec son ballon de sable
#   FR (Beam- 3)  : un chien blanc avec des taches brunes creusant avec ses barres le sable
#   FR (Beam- 4)  : un chien blanc avec des taches brunes creusant avec ses barres le sable
#   FR (Beam- 5)  : un chien blanc avec des taches brunes creusant avec ses barres le sable
# --------------------------------------------------------------------------------
# Example 41:
#   EN (Original) : a cat or dog trying to play the piano .
#   FR (Reference): un chat ou un chien qui essaie de jouer du piano .
#   FR (Greedy)   : un chat ou un chien essayant de <unk> les <unk> .
#   FR (Beam- 3)  : un chat ou un chien essayant de jouer au piano .
#   FR (Beam- 4)  : un chat ou un chien essayant de jouer au piano .
#   FR (Beam- 5)  : un chat ou un chien essayant de jouer au piano .
# --------------------------------------------------------------------------------
# Example 42:
#   EN (Original) : a child with a blue brimmed hat staring intently at something behind a fence .
#   FR (Reference): un enfant avec un chapeau à bord bleu regarde fixement quelque chose derrière une barrière .
#   FR (Greedy)   : un enfant avec un chapeau à bords bleu regardant attentivement quelque chose derrière une clôture .
#   FR (Beam- 3)  : un enfant avec un bonnet à bords bleu regardant attentivement quelque chose derrière une clôture .
#   FR (Beam- 4)  : un enfant avec un bonnet à bords bleu regardant attentivement quelque chose derrière une clôture .
#   FR (Beam- 5)  : un enfant avec un bonnet à bords bleu regardant attentivement quelque chose derrière une clôture .
# --------------------------------------------------------------------------------
# Example 43:
#   EN (Original) : this image is of a little girl leaning against her parents bed while she 's looking at herself in the mirror .
#   FR (Reference): c' est l' image d' une petite fille appuyée contre le lit de ses parents pendant qu' elle observe son reflet dans le miroir .
#   FR (Greedy)   : cette image d' une petite fille penchée contre ses lit , tandis qu' elle se tient le le au au miroir .
#   FR (Beam- 3)  : cette image d' une petite fille se adossée contre son lit , tandis qu' elle se regarde en le dans le miroir .
#   FR (Beam- 4)  : cette image d' une petite fille se adossée contre son lit , tandis qu' elle se tient le le dans le miroir .
#   FR (Beam- 5)  : cette image d' une petite fille se adossée contre son lit , tandis qu' elle se tient le le dans le miroir .
# --------------------------------------------------------------------------------
# Example 44:
#   EN (Original) : a black girl hanging upside down with her little braids dragging the ground .
#   FR (Reference): une fille à la peau mate à l' envers avec ses petites tresses qui touchent le sol .
#   FR (Greedy)   : une fille noire finit la tête en bas avec sa petite petite petite petite .
#   FR (Beam- 3)  : une fille noire finit la tête en bas avec son petit tirant tirant par sol .
#   FR (Beam- 4)  : une fille noire finit la tête en bas avec son petit tirant tirant par sol .
#   FR (Beam- 5)  : une fille noire finit la tête en bas avec son petit tirant tirant par sol .
# --------------------------------------------------------------------------------
# Example 45:
#   EN (Original) : a black and white image of a woman in a coffee shop , and a reflection of a car in the window .
#   FR (Reference): une image en noir et blanc d' une femme à un café , et le reflet d' une voiture dans la fenêtre .
#   FR (Greedy)   : une photo noire et blanc d' une femme dans un café , et un reflet d' une voiture dans la fenêtre .
#   FR (Beam- 3)  : une photo noire et blanc d' une femme dans un café , et un reflet d' une voiture dans la fenêtre .
#   FR (Beam- 4)  : une photo noire et blanc d' une femme dans un café , et un reflet d' une voiture dans la fenêtre .
#   FR (Beam- 5)  : une photo noire et blanc d' une femme dans un café , et un reflet d' une voiture dans la fenêtre .
# --------------------------------------------------------------------------------
# Example 46:
#   EN (Original) : black dog coming out of the beach with a toy on his trunk
#   FR (Reference): un chien noir sort de la plage avec un jouet dans la bouche .
#   FR (Greedy)   : un chien noir sortant hors de la plage avec un jouet sur son dos
#   FR (Beam- 3)  : un chien noir sortant hors de la plage avec un jouet sur son dos
#   FR (Beam- 4)  : un chien noir sortant hors de la plage avec un jouet sur son dos
#   FR (Beam- 5)  : un chien noir sortant hors de la plage avec un jouet sur son dos
# --------------------------------------------------------------------------------
# Example 47:
#   EN (Original) : girls have suckers as they wear plastic over their costumes .
#   FR (Reference): les filles ont des sucettes tout en portant du plastique par - dessus leurs costumes .
#   FR (Greedy)   : des filles ont des signes tandis qu' elles ont en en au-dessus de leurs leurs leurs .
#   FR (Beam- 3)  : des filles ont des signes tandis qu' elles ont en en au-dessus de leurs bouteilles .
#   FR (Beam- 4)  : des filles ont des signes tandis qu' elles ont en en au-dessus de leurs bouteilles .
#   FR (Beam- 5)  : des filles ont des signes tandis qu' elles ont en en au-dessus de leurs bouteilles .
# --------------------------------------------------------------------------------
# Example 48:
#   EN (Original) : a man holds and speaks through a megaphone in the street
#   FR (Reference): un homme parle à travers un mégaphone dans la rue .
#   FR (Greedy)   : un homme tient tient et parle dans un mégaphone dans la rue
#   FR (Beam- 3)  : un homme tient et parle dans un mégaphone dans la rue
#   FR (Beam- 4)  : un homme tient et parle dans un mégaphone dans la rue
#   FR (Beam- 5)  : un homme tient et parle dans un mégaphone dans la rue
# --------------------------------------------------------------------------------
# Example 49:
#   EN (Original) : six children of different races stand in front of a wooden fence
#   FR (Reference): six enfants de race différente se tiennent debout devant une barrière en bois .
#   FR (Greedy)   : six enfants d' différentes races se reposent devant une clôture en bois
#   FR (Beam- 3)  : six enfants d' différentes races se reposent devant une clôture en bois
#   FR (Beam- 4)  : six enfants d' différentes races se reposent devant une clôture en bois
#   FR (Beam- 5)  : six enfants d' différentes races se reposent devant une clôture en bois
# --------------------------------------------------------------------------------
# Example 50:
#   EN (Original) : a child is dressed in all white with a white painted face .
#   FR (Reference): un enfant est habillé tout en blanc avec de la peinture blanche sur le visage .
#   FR (Greedy)   : un enfant est déguisé tout en blanc avec un visage peint .
#   FR (Beam- 3)  : un enfant est habillé tout en blanc avec le visage peint .
#   FR (Beam- 4)  : un enfant est habillé tout en blanc avec le visage peint .
#   FR (Beam- 5)  : un enfant est habillé tout en blanc avec le visage peint .
# --------------------------------------------------------------------------------
# Example 51:
#   EN (Original) : a man in a yellow biking shirt and sunglasses walks along a street .
#   FR (Reference): un homme avec un maillot jaune de cycliste et des lunettes de soleil marche dans la rue .
#   FR (Greedy)   : un homme avec un t - shirt jaune et des lunettes de soleil marche le long d' une rue .
#   FR (Beam- 3)  : un homme avec un t - shirt jaune et des lunettes de soleil marche le long d' une rue .
#   FR (Beam- 4)  : un homme avec un t - shirt jaune et des lunettes de soleil marche le long d' une rue .
#   FR (Beam- 5)  : un homme avec un t - shirt jaune et des lunettes de soleil marche le long d' une rue .
# --------------------------------------------------------------------------------
# Example 52:
#   EN (Original) : a dog rests in the grass while its owner looks on .
#   FR (Reference): un chien se repose dans l' herbe pendant que son propriétaire l' observe .
#   FR (Greedy)   : un chien se repose dans l' herbe tandis que son propriétaire surveille .
#   FR (Beam- 3)  : un chien se repose dans l' herbe tandis que son propriétaire surveille .
#   FR (Beam- 4)  : un chien se repose dans l' herbe tandis que son propriétaire surveille .
#   FR (Beam- 5)  : un chien se repose dans l' herbe tandis que son propriétaire surveille .
# --------------------------------------------------------------------------------
# Example 53:
#   EN (Original) : a woman laughs and hugs her dog as they sit on a grassy lawn together .
#   FR (Reference): une femme rit et prend son chien dans les bras pendant qu' ils sont assis ensemble sur une pelouse bien verte .
#   FR (Greedy)   : une femme rit et fait ses chien tandis qu' elle sont assis sur un pelouse d' une pelouse .
#   FR (Beam- 3)  : une femme rit et fait ses chien tandis qu' elle sont assis sur un pelouse ensemble .
#   FR (Beam- 4)  : une femme rit et fait ses chien tandis qu' elle sont assis sur un pelouse ensemble .
#   FR (Beam- 5)  : une femme rit et fait ses chien tandis qu' elle sont assis sur un pelouse ensemble .
# --------------------------------------------------------------------------------
# Example 54:
#   EN (Original) : a blurry shot of someone walking through a terminal .
#   FR (Reference): une photo floue de quelqu' un qui marche à travers un terminal .
#   FR (Greedy)   : une photo floue de quelqu' un marchant dans un gare .
#   FR (Beam- 3)  : une photo floue de quelqu' un marchant dans une gare .
#   FR (Beam- 4)  : une photo floue de quelqu' un marchant dans une gare .
#   FR (Beam- 5)  : une photo floue de quelqu' un marchant dans une gare .
# --------------------------------------------------------------------------------
# Example 55:
#   EN (Original) : a blond and white child with hands on waist
#   FR (Reference): un enfant blond et blanc avec ses mains sur la taille .
#   FR (Greedy)   : une jeune fille blonde et blanc avec les mains sur des <unk>
#   FR (Beam- 3)  : une jeune fille blonde et blanc avec les mains sur la main
#   FR (Beam- 4)  : une jeune fille blonde et blanc avec les mains en signe
#   FR (Beam- 5)  : une jeune fille blonde et blanc avec les mains en l' air
# --------------------------------------------------------------------------------
# Example 56:
#   EN (Original) : five white puppies huddled together with one licking the others snout .
#   FR (Reference): cinq chiots blancs blottis ensemble avec un qui lèche le museau d' un autre .
#   FR (Greedy)   : cinq agents blanches ensemble ensemble l' un , avec les autres personnes .
#   FR (Beam- 3)  : cinq agents blancs ont ensemble avec l' une d' entre elles les autres personnes .
#   FR (Beam- 4)  : cinq agents blancs ont ensemble avec l' une d' entre elles les autres personnes .
#   FR (Beam- 5)  : cinq agents blanches ensemble ensemble l' un d' entre elles se trouvent les autres .
# --------------------------------------------------------------------------------
# Example 57:
#   EN (Original) : a puppy is content on top of a red train .
#   FR (Reference): un chiot est content sur le toit d' un train rouge .
#   FR (Greedy)   : un chiot est sur sommet d' un train rouge .
#   FR (Beam- 3)  : un chiot est sur sommet d' un train rouge .
#   FR (Beam- 4)  : un chiot est sur sommet d' un train rouge .
#   FR (Beam- 5)  : un chiot est sur sommet d' un train rouge .
# --------------------------------------------------------------------------------
# Example 58:
#   EN (Original) : black dog with front legs out with one yellow bandage on one leg .
#   FR (Reference): un chien noir dont on voit les pattes avant , une portant un bandage jaune .
#   FR (Greedy)   : un chien noir avec pattes pattes avec un pattes jaune sur une patte .
#   FR (Beam- 3)  : un chien noir avec pattes pattes avec un pattes jaune sur une patte .
#   FR (Beam- 4)  : un chien noir avec pattes pattes avec un pattes jaune sur une patte .
#   FR (Beam- 5)  : un chien noir avec pattes pattes avec un pattes jaune sur une patte .
# --------------------------------------------------------------------------------
# Example 59:
#   EN (Original) : a young girl closes her eyes to enjoy the music of a guitarist on a stage .
#   FR (Reference): une jeune fille ferme les yeux pour profiter de la musique d' un guitariste sur scène .
#   FR (Greedy)   : une jeune fille avec ses yeux pour la la musique d' un d' un guitariste sur une scène .
#   FR (Beam- 3)  : une jeune fille avec ses yeux à la la musique d' la musique d' un guitariste .
#   FR (Beam- 4)  : une jeune fille en train de courir les yeux vers la musique d' un guitariste sur une scène .
#   FR (Beam- 5)  : une jeune fille en train de courir les yeux vers la musique d' un guitariste sur une scène .
# --------------------------------------------------------------------------------
# Example 60:
#   EN (Original) : black and white photo of a woman with her guitar accompanied by a friend
#   FR (Reference): une photo en noir et blanc d' une femme avec sa guitare , accompagnée par un ami .
#   FR (Greedy)   : une photo de noir et blanc d' une femme avec sa guitare , par un ami
#   FR (Beam- 3)  : une photo blanche et blanche sortant d' une femme avec sa guitare <unk> par un ami
#   FR (Beam- 4)  : une photo blanche et blanche sortant d' une femme avec sa guitare <unk> par un ami
#   FR (Beam- 5)  : une photo blanche et blanche sortant d' une femme avec sa guitare <unk> par un ami
# --------------------------------------------------------------------------------
# Example 61:
#   EN (Original) : this is a woman looking at her phone and a man beside her drinking from a bottle .
#   FR (Reference): c' est une femme qui regarde son téléphone et un homme à côté d' elle boit à la bouteille .
#   FR (Greedy)   : cette est une femme regardant son téléphone et un homme à côté de sa buvant dans une bouteille .
#   FR (Beam- 3)  : cette est une femme regardant son téléphone et un homme à côté buvant dans une bouteille .
#   FR (Beam- 4)  : cette est une femme regardant son téléphone et un homme à côté buvant dans une bouteille .
#   FR (Beam- 5)  : cette est une femme regardant son téléphone et un homme à côté buvant dans une bouteille .
# --------------------------------------------------------------------------------
# Example 62:
#   EN (Original) : black and white image of 3 men riding bicycles through a city street .
#   FR (Reference): une image en noir et blanc de trois hommes roulant à vélo à travers une rue .
#   FR (Greedy)   : des agents et des femmes blancs sont du trois hommes font du vélo dans une rue en ville .
#   FR (Beam- 3)  : des agents noires et blanc sont du trois hommes font du vélo dans une rue en ville .
#   FR (Beam- 4)  : des agents noires et blanc sont du trois hommes font du vélo dans une rue en ville .
#   FR (Beam- 5)  : des agents noires et blanc sont du trois hommes font du vélo dans une rue en ville .
# --------------------------------------------------------------------------------
# Example 63:
#   EN (Original) : brown dog carries a bag on his back and inside a puppy
#   FR (Reference): un chien brun porte un sac sur son dos et un chiot se trouve à l' intérieur .
#   FR (Greedy)   : un chien marron porte un sac sur son dos et dans un chiot
#   FR (Beam- 3)  : un chien marron porte un sac sur son dos et dans un chiot
#   FR (Beam- 4)  : un chien marron porte un sac sur son dos et dans un chiot
#   FR (Beam- 5)  : un chien marron porte un sac sur son dos et dans un chiot
# --------------------------------------------------------------------------------
# Example 64:
#   EN (Original) : three young people with a guitar resting on top of a mountain
#   FR (Reference): trois jeunes avec une guitare qui se reposent au sommet d' une montagne .
#   FR (Greedy)   : trois jeunes avec une guitare en train de au sommet d' une montagne
#   FR (Beam- 3)  : trois jeunes hommes avec une guitare en terre au sommet d' une montagne
#   FR (Beam- 4)  : trois jeunes hommes avec une guitare en terre au sommet d' une montagne
#   FR (Beam- 5)  : trois jeunes hommes avec une guitare en terre au sommet d' une montagne
# --------------------------------------------------------------------------------
# Example 65:
#   EN (Original) : a small girl and an old man do an acrobatic pirouette in front of a crowd in a street
#   FR (Reference): une petite fille et un vieillard font une pirouette acrobatique devant une foule dans la rue .
#   FR (Greedy)   : une petite fille et un homme plus âgé font une figure artistique devant une foule
#   FR (Beam- 3)  : une petite fille et un homme plus âgé font des vêtements devant une foule dans une rue
#   FR (Beam- 4)  : une petite fille et un homme plus âgé font des vêtements devant une foule dans une rue
#   FR (Beam- 5)  : une petite fille et un homme plus âgé font des vêtements devant une foule dans une rue
# --------------------------------------------------------------------------------
# Example 66:
#   EN (Original) : a tan dog splashes in a body of still water
#   FR (Reference): un labrador s' éclabousse dans une étendue d' eau calme .
#   FR (Greedy)   : un chien brun fait des éclaboussures dans une étendue d' eau
#   FR (Beam- 3)  : un chien brun fait des éclaboussures dans une étendue d' eau
#   FR (Beam- 4)  : un chien brun fait des éclaboussures dans une étendue d' eau
#   FR (Beam- 5)  : un chien brun fait des éclaboussures dans une étendue d' eau
# --------------------------------------------------------------------------------
# Example 67:
#   EN (Original) : a small dog giving a big jump to catch the ball
#   FR (Reference): un petit chien saute très haut pour attraper la balle .
#   FR (Greedy)   : un petit chien donnant un grand saut pour attraper la balle
#   FR (Beam- 3)  : un petit chien donnant un gros saut pour attraper la balle
#   FR (Beam- 4)  : un petit chien donnant un gros saut pour attraper la balle
#   FR (Beam- 5)  : un petit chien donnant un gros saut pour attraper la balle
# --------------------------------------------------------------------------------
# Example 68:
#   EN (Original) : two men in a boat with a boy sitting on the bow holding a bottle .
#   FR (Reference): deux hommes dans un bateau avec un garçon assis sur la proue tenant une bouteille .
#   FR (Greedy)   : deux hommes dans un bateau avec un garçon assis sur le podium , tenant une bouteille .
#   FR (Beam- 3)  : deux hommes dans un bateau avec un garçon assis sur le siège tenant une bouteille .
#   FR (Beam- 4)  : deux hommes dans un bateau avec un garçon assis sur le siège tenant une bouteille .
#   FR (Beam- 5)  : deux hommes dans un bateau avec un garçon assis sur le siège tenant une bouteille .
# --------------------------------------------------------------------------------
# Example 69:
#   EN (Original) : black and white picture of a girl hanging upside down and giving thumbs up
#   FR (Reference): une image en noir et blanc d' une fille suspendue à l' envers et qui donne des pouces vers le haut .
#   FR (Greedy)   : une photo de blanc et blanc d' une fille se la tête en bas et en bas vers le haut
#   FR (Beam- 3)  : chien noir et blanc d' une fille se la tête en bas et le pouce vers le haut
#   FR (Beam- 4)  : une photo noir et blanc d' une fille accrochant la tête en bas et le pouce vers le haut
#   FR (Beam- 5)  : une photo noir et blanc d' une fille accrochant la tête en bas et le pouce vers le haut
# --------------------------------------------------------------------------------
# Example 70:
#   EN (Original) : a man with a beard is seen through a window holding a cup , while a man in the background reads a newspaper .
#   FR (Reference): on peut voir un homme barbu à travers une fenêtre tenir un gobelet , pendant qu' un homme en arrière-plan lit un journal .
#   FR (Greedy)   : un homme portant une barbe est à travers une fenêtre , tenant un gobelet , tandis qu' un homme en arrière-plan lit un journal .
#   FR (Beam- 3)  : un homme portant une barbe est à travers une fenêtre , tenant un gobelet , tandis qu' un homme en arrière-plan lit un journal .
#   FR (Beam- 4)  : un homme portant une barbe est à travers une fenêtre , tenant un gobelet , tandis qu' un homme en arrière-plan lit un journal .
#   FR (Beam- 5)  : un homme portant une barbe est à travers une fenêtre , tenant un gobelet , tandis qu' un homme en arrière-plan lit un journal .
# --------------------------------------------------------------------------------
# Example 71:
#   EN (Original) : five young children making heart shapes with their hands .
#   FR (Reference): 5 enfants qui font des cœurs avec leurs mains .
#   FR (Greedy)   : cinq jeunes enfants font des fête avec leurs mains .
#   FR (Beam- 3)  : cinq jeunes enfants font des fête avec leurs mains .
#   FR (Beam- 4)  : cinq jeunes enfants font des fête avec leurs mains .
#   FR (Beam- 5)  : cinq jeunes enfants font des fête avec leurs mains .
# --------------------------------------------------------------------------------
# Example 72:
#   EN (Original) : a large white dog trying to get on a wooden deck while in the water of a lake .
#   FR (Reference): un grand chien blanc essaie de monter sur une plateforme en bois tout en étant dans l' eau du lac .
#   FR (Greedy)   : un grand chien blanc essayant de récupérer un en bois en bois tout en étant dans dans l' eau .
#   FR (Beam- 3)  : un grand chien blanc essayant d' attraper en bois en bois tout en étant dans l' eau d' un lac .
#   FR (Beam- 4)  : un grand chien blanc essayant d' attraper en bois en bois tout en étant dans l' eau d' un lac .
#   FR (Beam- 5)  : un grand chien blanc essayant d' attraper en bois en bois tout en étant dans l' eau d' un lac .
# --------------------------------------------------------------------------------
# Example 73:
#   EN (Original) : black and white image of a little boy riding a big bicycle through the grass .
#   FR (Reference): une image en noir et blanc d' un petit garçon qui roule avec un grand vélo à travers la verdure .
#   FR (Greedy)   : un d' noir noir et blanc d' un petit garçon faisant un grand vélo dans l' herbe .
#   FR (Beam- 3)  : un staffordshire noir et blanc d' un petit garçon faisant un grand vélo dans l' herbe .
#   FR (Beam- 4)  : un staffordshire noir et blanc d' un petit garçon chevauchant un gros vélo dans l' herbe .
#   FR (Beam- 5)  : un staffordshire noir et blanc d' un petit garçon chevauchant un gros vélo dans l' herbe .
# --------------------------------------------------------------------------------
# Example 74:
#   EN (Original) : two young women pause next to a wall in order to look at a cell phone .
#   FR (Reference): deux jeunes femmes s' arrêtent près d' un mur pour regarder leur téléphone .
# ...
#   FR (Reference): une foule rassemblée dans un milieu urbain utilise des parapluies et des ponchos en plastique pour se protéger de la pluie .
#   FR (Greedy)   : une foule rassemblée rassemblée avec des parapluies et des en plastique et en plastique pour se protéger sous la pluie .
#   FR (Beam- 3)  : une foule rassemblée dans un environnement urbain , avec des parapluies et des en plastique pour <unk> la pluie .
#   FR (Beam- 4)  : une foule rassemblée dans un environnement urbain , avec des parapluies et des en plastique pour <unk> la pluie .
#   FR (Beam- 5)  : une foule rassemblée dans un environnement urbain , avec des parapluies et des en plastique pour <unk> la pluie .
# --------------------------------------------------------------------------------
# Example 76:
#   EN (Original) : a person jumps off of a high cliff into a river below .
#   FR (Reference): une personne saute dans la rivière ci-dessous depuis une haute falaise .
#   FR (Greedy)   : une personne saute d' une falaise haute dans une rivière en dessous .
#   FR (Beam- 3)  : une personne saute d' une haute falaise dans une rivière en dessous .
#   FR (Beam- 4)  : une personne saute d' une haute falaise dans une rivière en dessous .
#   FR (Beam- 5)  : une personne saute d' une haute falaise dans une rivière en dessous .
# --------------------------------------------------------------------------------
# Example 77:
#   EN (Original) : a person on a floating raft over the rapids of a river
#   FR (Reference): une personne dans un canot pneumatique sur les rapides d' une rivière
#   FR (Greedy)   : une personne sur un radeau flottant au-dessus de la d' une rivière
#   FR (Beam- 3)  : une personne sur un radeau flottant au-dessus des rapides d' une rivière
#   FR (Beam- 4)  : une personne sur un radeau flottant au-dessus des rapides d' une rivière
#   FR (Beam- 5)  : une personne sur un radeau flottant au-dessus des rapides d' une rivière
# --------------------------------------------------------------------------------
# Example 78:
#   EN (Original) : two children jumping and running down a hill .
#   FR (Reference): deux enfants sautent et descendent une colline en courant .
#   FR (Greedy)   : deux enfants sautant et courant sur une colline .
#   FR (Beam- 3)  : deux enfants sautant et courant sur une colline .
#   FR (Beam- 4)  : deux enfants sautant et courant sur une colline .
#   FR (Beam- 5)  : deux enfants sautant et courant sur une colline .
# --------------------------------------------------------------------------------
# Example 79:
#   EN (Original) : a young child with a red sweater is jumping rope on a city sidewalk .
#   FR (Reference): un enfant avec un chandail rouge saute à la corde sur un trottoir .
#   FR (Greedy)   : un jeune enfant avec un sweat rouge saute à la corde sur un trottoir en ville .
#   FR (Beam- 3)  : un jeune enfant avec un sweat rouge saute à la corde sur un trottoir en ville .
#   FR (Beam- 4)  : un jeune enfant avec un sweat rouge saute à la corde sur un trottoir en ville .
#   FR (Beam- 5)  : un jeune enfant avec un sweat rouge saute à la corde sur un trottoir en ville .
# --------------------------------------------------------------------------------
# Example 80:
#   EN (Original) : person behind window sill offering liquor with person standing outside of window opening .
#   FR (Reference): une personne derrière le rebord d' une fenêtre offre de la liqueur à une personne qui se trouve dehors , derrière l' ouverture de la fenêtre .
#   FR (Greedy)   : une personne derrière une fenêtre de rideau , de personne debout avec personne debout devant une fenêtre ouverte .
#   FR (Beam- 3)  : une personne derrière une fenêtre , des vêtements et une personne debout devant une fenêtre ouverte .
#   FR (Beam- 4)  : une personne derrière une fenêtre , des vêtements et une personne debout devant une fenêtre ouverte .
#   FR (Beam- 5)  : une personne derrière une fenêtre , des vêtements et une personne debout devant une fenêtre ouverte .
# --------------------------------------------------------------------------------
# Example 81:
#   EN (Original) : a large white dog standing on a wooden dock watching a duck swimming in a lake .
#   FR (Reference): un grand chien blanc sur une plateforme en bois qui regarde un canard nager dans un lac .
#   FR (Greedy)   : un gros chien blanc debout sur un quai en bois regardant un canard nager dans un lac .
#   FR (Beam- 3)  : un gros chien blanc debout sur un quai en bois regardant un canard nager dans un lac .
#   FR (Beam- 4)  : un gros chien blanc debout sur un quai en bois regardant un canard nager dans un lac .
#   FR (Beam- 5)  : un gros chien blanc debout sur un quai en bois regardant un canard nager dans un lac .
# --------------------------------------------------------------------------------
# Example 82:
#   EN (Original) : a dog in the water overlooking a sunset .
#   FR (Reference): un chien dans l' eau qui regarde un coucher de soleil .
#   FR (Greedy)   : un chien dans l' eau , s' arrête coucher du soleil .
#   FR (Beam- 3)  : un chien dans l' eau surplombant un coucher de soleil .
#   FR (Beam- 4)  : un chien dans l' eau surplombant un coucher de soleil .
#   FR (Beam- 5)  : un chien dans l' eau surplombant un coucher de soleil .
# --------------------------------------------------------------------------------
# Example 83:
#   EN (Original) : a white dog chews on an empty plastic bottle while standing in a body of water
#   FR (Reference): un chien blanc mâchouille une bouteille vide en plastique tout en se tenant dans une étendue d' eau .
#   FR (Greedy)   : un chien blanc mâche un objet en plastique plastique , debout dans un plan d' eau
#   FR (Beam- 3)  : un chien blanc mâche un objet en plastique plastique , debout dans un plan d' eau
#   FR (Beam- 4)  : un chien blanc mâche un objet en plastique plastique , debout dans un plan d' eau
#   FR (Beam- 5)  : un chien blanc mâche un objet en plastique plastique , debout dans un plan d' eau
# --------------------------------------------------------------------------------
# Example 84:
#   EN (Original) : a girl is sitting in the grass next to a white dog .
#   FR (Reference): une fille est assise dans l' herbe à côté d' un chien blanc .
#   FR (Greedy)   : une fille est assise dans l' herbe à côté d' un chien blanc .
#   FR (Beam- 3)  : une fille est assise dans l' herbe à côté d' un chien blanc .
#   FR (Beam- 4)  : une fille est assise dans l' herbe à côté d' un chien blanc .
#   FR (Beam- 5)  : une fille est assise dans l' herbe à côté d' un chien blanc .
# --------------------------------------------------------------------------------
# Example 85:
#   EN (Original) : girl in unusual face mask with other people beside her .
#   FR (Reference): une fille portant un masque facial inhabituel avec d' autres personnes à côté d' elle .
#   FR (Greedy)   : une fille avec un visage peint visage avec d' autres personnes à côté d' elle .
#   FR (Beam- 3)  : une fille avec le visage peint avec d' autres personnes à côté d' elle .
#   FR (Beam- 4)  : une fille avec le visage peint avec d' autres personnes à côté d' elle .
#   FR (Beam- 5)  : une fille avec le visage peint avec d' autres personnes à côté d' elle .
# --------------------------------------------------------------------------------
# Example 86:
#   EN (Original) : a woman holds her dog 's face in her face and prepares to kiss it .
#   FR (Reference): une femme tient le visage de son chien entre ses mains et s' apprête à l' embrasser .
#   FR (Greedy)   : une femme tient le visage d' son visage dans son visage et se prépare à qu' il se prépare .
#   FR (Beam- 3)  : une femme tient le visage d' son visage dans son visage et se prépare à lui .
#   FR (Beam- 4)  : une femme tient le visage d' son visage dans son visage et se prépare à lui .
#   FR (Beam- 5)  : une femme tient le visage d' son visage dans son visage et se prépare à lui .
# --------------------------------------------------------------------------------
# Example 87:
#   EN (Original) : a group of police officers in argentina in black and white .
#   FR (Reference): un groupe de policiers en argentine en noir et blanc .
#   FR (Greedy)   : un groupe de policiers en en noir et blanc .
#   FR (Beam- 3)  : un groupe de policiers en en noir et blanc .
#   FR (Beam- 4)  : un groupe de policiers en en noir et blanc .
#   FR (Beam- 5)  : un groupe de policiers en en noir et blanc .
# --------------------------------------------------------------------------------
# Example 88:
#   EN (Original) : someone jumping off of a large cliff into a mountain lake .
#   FR (Reference): quelqu' un saute dans un lac de montagne depuis une grande falaise .
#   FR (Greedy)   : quelqu' un sautant d' une grande falaise dans un lac .
#   FR (Beam- 3)  : quelqu' un sautant d' une grande falaise dans un lac .
#   FR (Beam- 4)  : quelqu' un sautant d' une grande falaise dans un lac .
#   FR (Beam- 5)  : quelqu' un sautant d' une grande falaise dans un lac .
# --------------------------------------------------------------------------------
# Example 89:
#   EN (Original) : a painter is painting a larger version of a picture .
#   FR (Reference): un peintre en plein travail sur une version plus large d' une image .
#   FR (Greedy)   : un peintre peint un gros bâton dans une photo .
#   FR (Beam- 3)  : un peintre peint un gros bâton dans une photo .
#   FR (Beam- 4)  : un peintre peint un gros bâton dans une photo .
#   FR (Beam- 5)  : un peintre peint un gros bâton dans une photo .
# --------------------------------------------------------------------------------
# Example 90:
#   EN (Original) : a man and a woman look at flyers stuck in a glass .
#   FR (Reference): un homme et une femme qui regardent des flyers collés sur une vitre .
#   FR (Greedy)   : un homme et une femme regardent des cartes dans un verre .
#   FR (Beam- 3)  : un homme et une femme regardent des produits dans un verre .
#   FR (Beam- 4)  : un homme et une femme regardent des produits dans un verre .
#   FR (Beam- 5)  : un homme et une femme regardent des produits dans un verre .
# --------------------------------------------------------------------------------
# Example 91:
#   EN (Original) : a beach house next to sand and a group of people in the background of a black and white shot .
#   FR (Reference): une maison de plage à côté du sable et un groupe de personnes au fond d' une image en noir et blanc .
#   FR (Greedy)   : une plage de motocyclette à côté d' un groupe de personnes en arrière-plan et un groupe de personnes en arrière-plan noire .
#   FR (Beam- 3)  : une plage de soleil à côté d' un groupe de personnes en arrière-plan et un groupe de gens en arrière-plan .
#   FR (Beam- 4)  : une une plage près de sable et un groupe de personnes en arrière-plan et un groupe de personnes noire .
#   FR (Beam- 5)  : une une plage près de sable et un groupe de personnes en arrière-plan et un groupe de personnes noire .
# --------------------------------------------------------------------------------
# Example 92:
#   EN (Original) : a child wears a pair of goggles in front of a uhaul
#   FR (Reference): un enfant porte des lunettes de protection devant un camion u - haul .
#   FR (Greedy)   : un enfant porte un paire de lunettes dans une boutique
#   FR (Beam- 3)  : un enfant porte un paire de lunettes dans un verre
#   FR (Beam- 4)  : un enfant porte un paire de lunettes dans un verre
#   FR (Beam- 5)  : un enfant porte un paire de lunettes dans un verre
# --------------------------------------------------------------------------------
# Example 93:
#   EN (Original) : an old woman in a heavy jacket is eating of a plate on her lap .
#   FR (Reference): une vieille femme portant une grosse veste est en train de manger ce qu' il y a sur un plateau placé sur ses genoux .
#   FR (Greedy)   : une vieille femme en veste épais mange mange une assiette sur ses genoux .
#   FR (Beam- 3)  : une vieille femme en veste épais mange mange une assiette sur ses genoux .
#   FR (Beam- 4)  : une vieille femme en veste épais mange mange une assiette sur ses genoux .
#   FR (Beam- 5)  : une vieille femme en veste épais mange mange une assiette sur ses genoux .
# --------------------------------------------------------------------------------
# Example 94:
#   EN (Original) : a person is beginning to descend the stairs to the subway in a foreign country .
#   FR (Reference): une personne commence à descendre les escaliers qui vont l' amener au métro dans un pays étranger .
#   FR (Greedy)   : une personne répare le rythme d' un escalier dans un pays étranger .
#   FR (Beam- 3)  : une personne répare prépare à faire du escaliers dans un pays étranger .
#   FR (Beam- 4)  : une personne répare prépare à faire du escaliers dans un pays étranger .
#   FR (Beam- 5)  : une personne répare prépare à faire du escaliers dans un pays étranger .
# --------------------------------------------------------------------------------
# Example 95:
#   EN (Original) : the girl is at a playground wearing a colorful dress .
#   FR (Reference): la fille est sur une aire de jeux habillée d' une robe colorée .
#   FR (Greedy)   : la fille est un d' une robe colorée vêtue d' une robe colorée .
#   FR (Beam- 3)  : la fille est dans une robe colorée vêtue d' une robe colorée .
#   FR (Beam- 4)  : la jeune fille est un d' une robe colorée .
#   FR (Beam- 5)  : la jeune fille est un d' une robe colorée .
# --------------------------------------------------------------------------------
# Example 96:
#   EN (Original) : a person with arms extended wears a green and yellow parrot costume .
#   FR (Reference): une personne qui tend les bras et porte un costume de perroquet vert et jaune .
#   FR (Greedy)   : une personne avec les bras dessous d' une costume jaune et jaune .
#   FR (Beam- 3)  : une personne avec les bras dessous un costume jaune et jaune .
#   FR (Beam- 4)  : une personne avec les bras dessous un costume jaune et jaune .
#   FR (Beam- 5)  : une personne avec les bras dessous un costume jaune et jaune .
# --------------------------------------------------------------------------------
# Example 97:
#   EN (Original) : a man is walking by himself in front of a church .
#   FR (Reference): un homme marche tout seul devant une église .
#   FR (Greedy)   : un homme passe en train de se reposer devant une église .
#   FR (Beam- 3)  : un homme passe en passant devant une église .
#   FR (Beam- 4)  : un homme passe en passant devant une église .
#   FR (Beam- 5)  : un homme passe en passant devant une église .
# --------------------------------------------------------------------------------
# Example 98:
#   EN (Original) : a man plays a guitar and drinks a small coffee .
#   FR (Reference): un homme joue de la guitare et boit un petit café .
#   FR (Greedy)   : un homme joue de la guitare et boit un petit café .
#   FR (Beam- 3)  : un homme joue de la guitare et boit un petit café .
#   FR (Beam- 4)  : un homme joue de la guitare et boit un petit café .
#   FR (Beam- 5)  : un homme joue de la guitare et boit un petit café .
# --------------------------------------------------------------------------------
# Example 99:
#   EN (Original) : a man going down the stairs of the subway of the city
#   FR (Reference): un homme descend les escaliers du métro de la ville .
#   FR (Greedy)   : un homme descendant les escaliers de la ville
#   FR (Beam- 3)  : un homme descendant les escaliers de métro ville
#   FR (Beam- 4)  : un homme descendant les escaliers de métro ville
#   FR (Beam- 5)  : un homme descendant les escaliers de métro ville
# --------------------------------------------------------------------------------
# Example 100:
#   EN (Original) : a man walks dow a dirt path on the side of the road .
#   FR (Reference): un homme descend le long d' une route sale .
#   FR (Greedy)   : un homme marche marche devant un chemin de terre au bord de la route .
#   FR (Beam- 3)  : un homme marche avec un chemin de terre au bord de la route .
#   FR (Beam- 4)  : un homme marche avec un chemin de terre au bord de la route .
#   FR (Beam- 5)  : un homme marche avec un chemin de terre au bord de la route .
# --------------------------------------------------------------------------------
